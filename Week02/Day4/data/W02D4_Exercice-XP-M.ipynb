# %% [markdown]
# # Exercises XP
# Last Updated: January 27th, 2025
#
# ## 👩‍🏫 👩🏿‍🏫 What You’ll learn
# The importance of data visualization in data analysis.
# How to use Python libraries such as Matplotlib and Seaborn for creating effective visualizations.
# Choosing the right graph for different data types and purposes.
# Hands-on experience with creating and customizing various types of plots.
#
#
# ## 🛠️ What you will create
# Line plots for time-series data.
# Bar charts for category-wise comparisons.
# Histograms for distribution analysis.
# Scatter plots for identifying relationships between variables.

# %% [markdown]
# ## 🌟 Exercise 1: Understanding Data Visualization
# Task: Explain why data visualization is important in data analysis.
# Task: Describe the purpose of a line graph in data visualization.

# %% [markdown]
# ### ✅ **Pourquoi la visualisation de données est importante :**
# Elle permet de **comprendre rapidement** les tendances, les relations et les anomalies dans les données, ce qui facilite la prise de décision.
#
# ### ✅ **But d’un graphique en ligne (line graph) :**
# Il sert à **montrer l’évolution d’une variable dans le temps**, en mettant en évidence les tendances et les variations continues.

# %% [markdown]
# ##  🌟 Exercise 2: Creating a Line Plot for Temperature Variation
# Objective: Create a simple line plot using Matplotlib that represents temperature variations over a week.
# Tasks:
# Use a list of temperature values for each day of the week (e.g., [72, 74, 76, 80, 82, 78, 75]).
# Label the x-axis as “Day” and the y-axis as “Temperature (°F)”.
# Add a title to the plot.
# Display the plot.

# %%
import matplotlib.pyplot as plt

# Données
jours = ["Lun", "Mar", "Mer", "Jeu", "Ven", "Sam", "Dim"]
temperatures = [72, 74, 76, 80, 82, 78, 75]

# Création du graphique
plt.plot(jours, temperatures)               # tracer la ligne
plt.xlabel("Day")                           # étiquette axe X
plt.ylabel("Temperature (°F)")              # étiquette axe Y
plt.title("Temperature Variation Over a Week")  # titre
plt.grid(True)                              # grille

plt.show()                                  # affichage

# %% [markdown]
# ## Exercise 3: Visualizing Monthly Sales with a Bar Chart
# Objective: Generate a bar chart using Matplotlib to visualize monthly sales data for a retail store.
# Tasks:
# Create a list of sales values for each month (e.g., [5000, 5500, 6200, 7000, 7500]).
# Label the x-axis as “Month” and the y-axis as “Sales Amount ($)”.
# Add a title to the bar chart.
# Display the plot.

# %%
import matplotlib.pyplot as plt

# Créer Données
mois = ["Jan", "Fév", "Mar", "Avr", "Mai"]
ventes = [5000, 5500, 6200, 7000, 7500]

# Créer graphique à barres
plt.bar(mois, ventes)

# Étiquettes et titre
plt.xlabel("Month")
plt.ylabel("Sales Amount ($)")
plt.title("Monthly Sales Data for Retail Store")
plt.grid(axis='y')  # Grille horizontale (optionnel)

# Afficher
plt.show()

# %% [markdown]
# ##  Exercise 4: Visualizing the Distribution of CGPA
# Objective: Create a histogram to visualize the distribution of students’ CGPA.
# Dataset Overview: Assume the CGPA data is categorized into ranges and loaded in a DataFrame named df.
# Tasks:
# Import necessary libraries.
# Use Seaborn’s histplot to create a histogram of the CGPA categories.
# Customize the histogram with a specific color and add a title.
# Display the plot.

# %%
# Importer bibliothèques nécessaires
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Créer DataFrame avec des CGPA fictifs
df = pd.DataFrame({
    'CGPA': [2.5, 3.0, 3.2, 3.5, 3.5, 3.7, 3.8, 3.9, 4.0, 2.8, 3.1, 2.9, 3.6, 3.3, 3.0, 3.2]
})

# %%
# Créer histogramme avec Seaborn
sns.histplot(data=df, x="CGPA", color="skyblue", bins=8)

# Ajouter titre
plt.title("Distribution des CGPA des étudiants")

# Afficher
plt.show()

# %% [markdown]
# ### Même exercice avec base données Student Mental Health

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Charger le fichier
df = pd.read_csv("Student Mental health.csv")

# Convertir le CGPA en numérique (au cas où ce serait au format string)
df['CGPA'] = pd.to_numeric(df['What is your CGPA?'], errors='coerce')

# Créer l'histogramme
sns.histplot(df['CGPA'], bins=10, color='skyblue', kde=True)

# Personnalisation
plt.title("Distribution des CGPA des étudiants")
plt.xlabel("CGPA")
plt.ylabel("Nombre d'étudiants")
plt.show()

# %% [markdown]
# Le graphique plat que tu obtiens signifie probablement que la colonne What is your CGPA? contient des valeurs non numériques (ex. : chaînes de texte comme "3.5 / 4.0", "3.2" avec des caractères spéciaux, ou valeurs manquantes).

# %% [markdown]
# ### Vérifier le contenu réel de la colonne CGPA :

# %%
print(df['What is your CGPA?'].unique())
# Out:
# ['3.00 - 3.49' '3.50 - 4.00' '3.50 - 4.00 ' '2.50 - 2.99' '2.00 - 2.49'
#  '0 - 1.99']

# %% [markdown]
# ### Nettoyer colonne pour extraire les valeurs numériques :

# %%
# Nettoyage : garder uniquement les parties numériques avant conversion
df['CGPA_clean'] = df['What is your CGPA?'].str.extract(r'(\d+\.\d+)')
df['CGPA_clean'] = pd.to_numeric(df['CGPA_clean'], errors='coerce')

# %% [markdown]
# ### Barplot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Charger le fichier
df = pd.read_csv("Student Mental health.csv")

# Nettoyer les espaces superflus
df['CGPA_category'] = df['What is your CGPA?'].str.strip()

# Compter et afficher avec un countplot
sns.countplot(x='CGPA_category', data=df, color='skyblue')
plt.title("Distribution des catégories de CGPA")
plt.xlabel("Tranche de CGPA")
plt.ylabel("Nombre d'étudiants")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Exercise 5: Comparing Anxiety Levels Across Different Genders
# Objective: Use a bar plot to compare the proportion of students experiencing anxiety across different genders.
# Dataset Overview: The dataset includes columns: ‘Do you have Anxiety?’ and ‘Choose your gender’.
# Tasks:
# Import necessary libraries.
# Use Seaborn to create a bar plot comparing anxiety levels across genders from the dataset df.
# Customize the plot with an appropriate color palette and add a title.
# Display the plot.

# %%
# Importer bibliothèques nécessaires
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Créer DataFrame avec données fictives
df = pd.DataFrame({
    'Choose your gender': ['Male', 'Female', 'Female', 'Male', 'Other', 'Female', 'Male', 'Other'],
    'Do you have Anxiety?': ['Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'Yes', 'No']
})

# %%
# Créer bar plot : proportion d'anxiété par genre
sns.set(style="whitegrid")
sns.countplot(data=df, x='Choose your gender', hue='Do you have Anxiety?', palette='pastel')

# Ajouter titre
plt.title("Anxiety Levels by Gender")

# Afficher
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Charger le fichier
df = pd.read_csv("Student Mental health.csv")

# Convertir les réponses en numérique : Yes = 1, No = 0
df['Anxiety'] = df['Do you have Anxiety?'].map({'Yes': 1, 'No': 0})

# Barplot : proportion d'étudiants avec anxiété par genre
sns.barplot(x='Choose your gender', y='Anxiety', data=df, palette='pastel')

# Personnalisation du graphique
plt.title("Proportion d'anxiété par genre")
plt.xlabel("Genre")
plt.ylabel("Proportion de 'Oui'")
plt.ylim(0, 1)
plt.show()
# Out:
# C:\Users\chume\AppData\Local\Temp\ipykernel_17180\3817454369.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Choose your gender', y='Anxiety', data=df, palette='pastel')

# %% [markdown]
# ## Exercise 6: Exploring the Relationship Between Age and Panic Attacks
# Objective: Create a scatter plot to explore the relationship between students’ age and the occurrence of panic attacks.
# Dataset Overview: The dataset includes columns: ‘Age’ and ‘Do you have Panic Attacks?’.
# Tasks:
# Import necessary libraries.
# Convert panic attack responses to numeric values (e.g., Yes=1, No=0).
# Use Seaborn’s scatterplot to create a scatter plot with ‘Age’ on the x-axis and numeric panic attack responses on the y-axis.
# Customize the plot to improve readability by adding labels, a title, and adjusting point styles.
# Display the plot.

# %%
# Importer bibliothèques
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Créer DataFrame avec des données fictives
df = pd.DataFrame({
    'Age': [18, 19, 20, 21, 22, 23, 24, 25],
    'Do you have Panic Attacks?': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No']
})

# %%
# Conversion des réponses en valeurs numériques : Yes=1, No=0
df['Panic_Attack_Numeric'] = df['Do you have Panic Attacks?'].map({'Yes': 1, 'No': 0})

# %%
# Créer scatter plot
sns.scatterplot(data=df, x='Age', y='Panic_Attack_Numeric', style='Do you have Panic Attacks?', s=100)

# Personnalisation
plt.title("Relation entre l'âge et les crises de panique")
plt.xlabel("Âge")
plt.ylabel("Panic Attack (1=Yes, 0=No)")
plt.yticks([0, 1], ['No', 'Yes'])

# Afficher
plt.show()

# %% [markdown]
# ## Alternatives

# %% [markdown]
# ### Sur demande

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Exemple de DataFrame
df['Panic'] = df['Do you have Panic Attacks?'].map({'Yes': 1, 'No': 0})

# Option 1 : barplot (moyenne de panic attacks par âge ou tranche)
df['AgeGroup'] = pd.cut(df['Age'], bins=[10, 15, 20, 25, 30], labels=['10-15', '15-20', '20-25', '25-30'])
sns.barplot(x='AgeGroup', y='Panic', data=df)
plt.title("Proportion de crises de panique par tranche d'âge")
plt.ylabel("Proportion de 'Oui'")
plt.xlabel("Tranche d'âge")
plt.show()

# %%
# Option 2 : boxplot
sns.boxplot(x='Do you have Panic Attacks?', y='Age', data=df)
plt.title("Distribution de l'âge selon les crises de panique")
plt.xlabel("Crises de panique")
plt.ylabel("Âge")
plt.show()

# %% [markdown]
# ## Utilisation des donnees du fichier fourni sur Student Mental Helth data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Charger le fichier CSV
df = pd.read_csv("Student Mental health.csv")

# 2. Afficher les colonnes pour identifier les bons noms
print(df.columns)
# Out:
# Index(['Timestamp', 'Choose your gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Charger le fichier
df = pd.read_csv("Student Mental health.csv")

# Conversion des réponses en numériques
df['Panic'] = df['Do you have Panic attack?'].map({'Yes': 1, 'No': 0})

# Barplot : proportion de panic attacks par âge
sns.barplot(x='Age', y='Panic', data=df)
plt.title("Proportion de crises de panique par âge")
plt.xlabel("Âge")
plt.ylabel("Proportion de 'Oui'")
plt.ylim(0, 1)
plt.show()

# %%
# Boxplot : distribution de l'âge selon la présence de crises de panique
sns.boxplot(x='Do you have Panic attack?', y='Age', data=df)
plt.title("Distribution de l'âge selon les crises de panique")
plt.xlabel("Crises de panique")
plt.ylabel("Âge")
plt.show()
