# %% [markdown]
# # Daily Challenge: Hands-On Image Transformation and Visualization
#
#
# ## 👩‍🏫 👩🏿‍🏫 What You’ll learn
# Data Augmentation
# Data visualization using MatPlotLib or PIL libraries.
#
#
# ## Your Task
# For this challenge, please use google colab.
#
# Load and Visualize Images using the Flower Color Images dataset

# %% [markdown]
# ### Load and Visualize Images using the Flower Color Images dataset

# %% [markdown]
# ### Install the libraries :

# %%
# !pip install tensorflow
! pip install keras
! pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# ...
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# ...
#    ---------------------------------------- 0.0/376.0 MB ? eta -:--:--
#    --- ----------------------------------- 31.5/376.0 MB 152.9 MB/s eta 0:00:03
#    -------- ------------------------------ 79.4/376.0 MB 187.6 MB/s eta 0:00:02
#    ------------ ------------------------- 122.7/376.0 MB 195.9 MB/s eta 0:00:02
# ...

# %% [markdown]
# ### To load an image and display it :

# %%
from PIL import Image, ImageOps

import matplotlib.pyplot as plt

from scipy.ndimage import rotate

import numpy as np

# %%
from PIL import Image
import matplotlib.pyplot as plt

image_path = 'Flower Color Images Dataset/flower_images/flower_images/0020.png'
original_image = Image.open(image_path)

plt.imshow(original_image)
plt.axis('off')
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

image_path = 'C:\\Users\\chume\\Desktop\\Flower Color Images Dataset\\flower_images\\flower_images\\0021.png'
original_image = Image.open(image_path)

plt.imshow(original_image)
plt.axis('off')
plt.show()

# %%
image_path = 'C:\\Users\\chume\\Desktop\\Flower Color Images Dataset\\flower_images\\flower_images\\0022.png'
original_image = Image.open(image_path)
plt.imshow(original_image)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Rotate an image by 45 degrees

# %%
from PIL import Image

def rotate_image_45_degrees(image):
    # Rotation dans le sens inverse des aiguilles d'une montre
    return image.rotate(45, expand=True)

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Charger l'image
image_path = 'C:/Users/chume/Desktop/Flower Color Images Dataset/flower_images/flower_images/0023.png'
original_image = Image.open(image_path)

# Appliquer la rotation
rotated_image = rotate_image_45_degrees(original_image)

# Afficher les deux images
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Originale")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(rotated_image)
plt.title("Rotée 45°")
plt.axis('off')

plt.show()

# %% [markdown]
# ### Flip an image horizontally and then vertically using mirror and flip functions from ImageOps

# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

# Charger l'image
image_path = 'C:/Users/chume/Desktop/Flower Color Images Dataset/flower_images/flower_images/0024.png'
original_image = Image.open(image_path)

# Flip horizontal (miroir gauche-droite)
horizontally_flipped = ImageOps.mirror(original_image)

# Flip vertical (haut-bas)
vertically_flipped = ImageOps.flip(original_image)

# Affichage
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(original_image)
plt.title("Originale")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(horizontally_flipped)
plt.title("Flip horizontal")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(vertically_flipped)
plt.title("Flip vertical")
plt.axis('off')

plt.show()

# %% [markdown]
# ### Zoom in on an image (scale by 1.2x) using .resize(...)

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Charger l'image
image_path = 'C:/Users/chume/Desktop/Flower Color Images Dataset/flower_images/flower_images/0025.png'
original_image = Image.open(image_path)

# Calculer la nouvelle taille (zoom 1.2x)
width, height = original_image.size
new_size = (int(width * 1.2), int(height * 1.2))

# Redimensionner (zoom avant)
zoomed_image = original_image.resize(new_size, resample=Image.LANCZOS)

# Affichage
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Originale")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(zoomed_image)
plt.title("Zoom 1.2x")
plt.axis('off')

plt.show()

# %% [markdown]
# ### Avec choix de l'agrandissement

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Demande du facteur de zoom
scale = float(input("Entrez le facteur de zoom (ex : 1.2 pour zoom, 0.8 pour rétrécir) : "))

# Charger l'image
image_path = 'C:/Users/chume/Desktop/Flower Color Images Dataset/flower_images/flower_images/0026.png'
original_image = Image.open(image_path)

# Taille originale
orig_width, orig_height = original_image.size

# Redimensionner selon le facteur
zoomed_width = int(orig_width * scale)
zoomed_height = int(orig_height * scale)
zoomed_image = original_image.resize((zoomed_width, zoomed_height), resample=Image.LANCZOS)

# Si zoom > 1 : recadrer au centre
if scale >= 1.0:
    left = (zoomed_width - orig_width) // 2
    top = (zoomed_height - orig_height) // 2
    right = left + orig_width
    bottom = top + orig_height
    final_image = zoomed_image.crop((left, top, right, bottom))
# Si zoom < 1 : ajouter bordure noire (centrer image réduite)
else:
    final_image = Image.new("RGB", (orig_width, orig_height), color=(0, 0, 0))
    paste_left = (orig_width - zoomed_width) // 2
    paste_top = (orig_height - zoomed_height) // 2
    final_image.paste(zoomed_image, (paste_left, paste_top))

# Affichage
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title("Originale")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(final_image)
plt.title(f"Zoom x{scale}")
plt.axis('off')
plt.show()
