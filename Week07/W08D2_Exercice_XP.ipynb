# %% [markdown]
# # Exercices XP
# Dernière mise à jour : 29 avril 2025
#
# ## 👩‍🏫 👩🏿‍🏫 Ce que vous apprendrez
# Identifier les degrés d’ouverture des LLM et ce que chacun permet
# Comprendre et comparer les licences open source
# Évaluer les points forts et les inconvénients des différents LLM ouverts
# Évaluer les modèles qui fonctionnent le mieux dans des cas d'utilisation ou des contraintes spécifiques
# Explorez les outils et communautés LLM ouverts, sans nécessiter de GPU
# Acquérir des compétences pratiques dans la sélection de modèles LLM et la préparation au déploiement
#
#
# ## 🛠️ Ce que vous allez créer
# Un tableau d'analyse comparative LLM
# Liste de contrôle de compatibilité des licences pour les produits SaaS
# Une réflexion sous forme de quiz sur la sélection des LLM
# Une liste de contrôle de préparation au déploiement local
# Un guide de correspondance de modèles basé sur des références
# Un plan de mise à niveau matérielle ou une comparaison coûts-avantages (local ou cloud)

# %% [markdown]
# # Exercice 1 : Réflexion sur les niveaux Open Source
#
# ## Qu'allez-vous utiliser
#
# - **Niveaux open source** : entièrement ouvert, poids publiés, architecture uniquement
# - **Composants du modèle** : architecture du modèle, poids pré-entraînés
# - **Concepts de recyclage** : réglage fin, adaptation au domaine
# - **Exigences du domaine** : sensibilité des données de santé, conformité
#
# ---
#
# ## Instructions étape par étape
#
# ### 1. Rassembler les définitions
#
# Localisez les descriptions des trois niveaux d’ouverture :
# - **Entièrement ouvert**
# - **Poids libérés**
# - **Architecture uniquement**
#
# Copiez ou surlignez chaque définition dans vos notes.
#
# ---
#
# ### 2. Identifier les caractéristiques clés
#
# Pour chaque niveau, notez deux points :
# - **Qu'est-ce qui est ouvert ?** (ex. : code, pondérations, les deux)
# - **Ce que vous pouvez et ne pouvez pas faire** (ex. : vous recycler, inspecter les éléments internes)
#
# ---
#
# ### 3. Comparez-les côte à côte
#
# | **Niveau d’ouverture** | **Qu'est-ce qui est ouvert ?** | **Impact sur la reconversion/modification** |
# |------------------------|-------------------------------|----------------------------------------------|
# | Entièrement ouvert     | Code + poids + architecture   | Vous pouvez inspecter, modifier et recycler l’ensemble du modèle. |
# | Poids libérés          | Poids uniquement              | Vous disposez des poids pour un réglage fin, mais pas du code complet. |
# | Architecture uniquement| Structure uniquement          | Vous connaissez la structure mais vous manquez de poids pré-entraînés. |
#
# ---
#
# ### 4. Rédigez votre paragraphe comparatif
#
# Rédigez un paragraphe de 3 à 5 phrases qui :
# - Définit chaque niveau d’ouverture avec vos propres mots.
# - Souligne un avantage ou une limitation principale de chacun.
#
# ---
#
# ### 5. Répondez à l'invite sur les soins de santé
#
# Réfléchissez à la création d’un assistant spécifique aux soins de santé qui doit être recyclé sur les données cliniques.
# Écrivez 1 à 2 phrases expliquant :
# - **Quel niveau d’ouverture est essentiel pour cette tâche.**
# - **Pourquoi ce niveau prend en charge le réglage fin spécifique au domaine.**
#
# ---
#
# ## Livrables
#
# - **Paragraphe comparatif** (3 à 5 phrases)
# - **Réponse rapide** (1 à 2 phrases)

# %% [markdown]
# Voici la réponse à l’exercice 2, de façon directe et complète :
#
# **Paragraphe comparatif**
# Un modèle **entièrement ouvert** met à disposition à la fois l’architecture et les poids pré-entraînés, ainsi que le code source. Il permet une inspection complète, une modification du modèle et un réglage fin. Un modèle avec **poids libérés** fournit les poids pré-entraînés mais pas nécessairement le code complet, permettant un réglage fin mais limitant la compréhension ou la modification de l’architecture. En revanche, un modèle avec **architecture uniquement** expose seulement la structure du réseau, sans poids pré-entraînés, ce qui empêche tout ajustement direct et nécessite un nouvel entraînement complet. Chaque niveau offre un degré différent de contrôle et d’adaptabilité.
#
# **Réponse rapide sur les soins de santé**
# Le niveau **entièrement ouvert** est essentiel pour créer un assistant médical, car il permet un réglage fin sur des données cliniques sensibles tout en assurant transparence et conformité.

# %% [markdown]
# # Exercice 2 : Vérification de la licence pour une utilisation SaaS
#
# ## Qu'allez-vous utiliser
#
# - **Sources du modèle** : pages du modèle Hugging Face (ex. : `mistralai/Mistral-7B-Instruct`, `meta-llama/Llama-2-7b-chat-hf`)
# - **Concepts de licence** : permissif vs. copyleft, clauses d'utilisation commerciale
# - **Types de restrictions** : limites d'utilisateurs, exigences d'attribution, contrôles d'exportation
# - **Outils de comparaison** : format de liste de contrôle, analyse côte à côte
#
# ---
#
# ## Instructions étape par étape
#
# ### 1. Sélectionnez vos modèles
#
# - Accédez aux modèles sur Hugging Face.
# - Choisissez deux modèles open source (par exemple :
#   - `mistralai/Mistral-7B-Instruct`
#   - `meta-llama/Llama-2-7b-chat-hf`)
# - Notez les URL de leurs pages modèles pour référence.
#
# ---
#
# ### 2. Localisez la section Licence
#
# - Sur la page de chaque modèle, faites défiler jusqu’au champ **« Licence »**.
# - Copiez le nom de la licence (ex. : Apache 2.0, CC BY 4.0, etc.) dans vos notes.
#
# ---
#
# ### 3. Déterminer les autorisations d'utilisation commerciale
#
# - Lisez le texte ou le résumé de la licence.
# - **Répondez** : L’utilisation commerciale est-elle explicitement autorisée, restreinte ou interdite ?
# - Rédigez une brève note sur les conditions (ex. : « autorisé avec attribution »).
#
# ---
#
# ### 4. Identifier les restrictions supplémentaires
#
# - Recherchez d’éventuelles clauses spéciales sur la page Hugging Face ou dans le texte de licence lié :
#   - Limites d’utilisateurs mensuelles (ex. : « jusqu’à 10 000 utilisateurs/mois »)
#   - Exigences d’attribution (ex. : « doit créditer les créateurs du modèle »)
#   - Déclarations de contrôle des exportations ou restrictions géographiques
# - Notez chaque restriction dans une courte phrase.
#
# ---
#
# ### 5. Créez votre liste de contrôle
#
# Créez une liste de contrôle **Markdown** avec une section par modèle :
#
# ```markdown
# - [ ] **Model Name**
#   - Type of license:
#     - [ ] License name
#   - Commercial use allowed:
#     - [ ] Yes / No / Conditional
#   - Restrictions:
#     - [ ] Restriction #1
#     - [ ] Restriction #2

# %% [markdown]
# Voici la réponse à l’exercice 2, de façon directe et complète :
#
# ---
#
# ##  Sélection des modèles
#
# * **mistralai/Mistral-7B-Instruct-v0.3**
#   URL : Hugging Face – page du modèle Mistral‑7B‑Instruct‑v0.3
# * **meta‑llama/Llama‑2‑7b‑chat‑hf**
#   URL : Hugging Face – page du modèle Llama 2 Chat 7B
#
# ---
#
# ##  Liste de contrôle Markdown
#
# ```markdown
# - [ ] **mistralai/Mistral‑7B‑Instruct‑v0.3**
#   - Type of license:
#     - [x] Apache 2.0 license
#   - Commercial use allowed:
#     - [x] Yes, sans restriction (Apache 2.0 autorise l’usage commercial librement)
#   - Restrictions:
#     - [ ] Attribution recommandée (pas imposée très strictement)
#     - [ ] Pas de contrôle d’exportation ou d’utilisateurs mentionnés
#
# - [ ] **Llama‑2‑7b‑chat‑hf (Llama 2 Community License)**
#   - Type of license:
#     - [x] Llama 2 Community License Agreement (source‑available / licence communautaire)
#   - Commercial use allowed:
#     - [x] Oui, **mais conditionnel** : autorisée sauf si plus de 700 millions d’utilisateurs actifs mensuels (sinon licence spéciale requise)
#   - Restrictions:
#     - [x] Attribution requise à Meta (texte à conserver dans NOTICE)
#     - [x] Interdit d’utiliser les sorties pour améliorer un autre modèle LLM (hors dérivés de Llama 2 ou œuvres dérivées)
#     - [x] Doit respecter la Acceptable Use Policy (incluant contrôles d’exportation)
#     - [x] Si plus de 700 M d’utilisateurs mensuels, licence commerciale distincte obligatoire
# ```
#
# ---
#
# ###  Résumé comparatif
#
# * **Mistral‑7B‑Instruct-v0.3** est sous licence Apache 2.0 : usage commercial autorisé sans condition, aucun plafond d’utilisateurs, très permissif .
#
# * **Llama 2 Chat 7B (Community License)** est source‑available, avec utilisation commerciale autorisée **mais soumise à conditions strictes**, notamment attribution, interdiction de réutiliser les sorties pour entraîner d’autres modèles, limitation à moins de 700 millions d’utilisateurs actifs par mois, et conformité à la politique d’utilisation acceptable de Meta .

# %% [markdown]
# # 🌟 Exercice 3 : Défi Matchmaker LLM
#
# ## Qu'allez-vous utiliser
#
# - **Exigences de l'équipe** : inférence CPU, contraintes des ordinateurs portables bas de gamme, support multilingue
# - **Critères de sélection du modèle** : vitesse d'inférence, taille du modèle, efficacité de l'architecture, performances de référence
# - **Ressources Hugging Face** : filtres, cartes modèles, balises (ex. : « mathématiques », « logique », « multilingue »)
# - **Mesures d'évaluation** : tests de latence, scores de raisonnement logique, résultats de référence en mathématiques, couverture linguistique
#
# ---
#
# ## Instructions étape par étape
#
# ### 1. Analyser les besoins de l'équipe
#
# Lisez les besoins de chaque équipe et soulignez la contrainte clé :
#
# - **LegalTech** : chatbot basé uniquement sur le **CPU** et la **logique**
# - **EdTech** : focus **mathématiques/logique** sur des **ordinateurs portables bas de gamme**
# - **ONG mondiale** : prise en charge de **plus de 5 langues**
#
# ---
#
# ### 2. Recherche sur Hugging Face
#
# - Accédez aux modèles sur Hugging Face
# - Appliquez des **filtres** adaptés :
#   - **Matériel** : modèles compatibles **CPU** ou **quantifiés**
#   - **Mots-clés** : « logique », « mathématiques », « multilingue »
#   - **Taille du modèle** : ≤ **7B paramètres**
#
# ---
#
# ### 3. Compiler les listes de candidats
#
# Pour chaque équipe, listez **3 à 5 modèles** correspondant aux filtres.
#
# Pour chaque modèle, notez :
# - Nombre de **paramètres**
# - **Architecture** (ex. : GPT-NeoX, MPT, BLOOM)
# - Toute **quantification ou optimisation** (ex. : 8 bits, int4)
# - **Scores de référence** (ex. : BoolQ, GSM8K, FLORES-200)
#
# ---
#
# ### 4. Évaluer par rapport aux critères
#
# - **LegalTech** : raisonnement logique fort (**BoolQ, ReClor**) et inférence CPU rapide
# - **EdTech** : bons scores **mathématiques** (**GSM8K, MATH**) et faible utilisation de RAM
# - **ONG mondiale** : modèles **hautement multilingues** (**FLORES-200, M2M100, BLOOM**)
#
# ---
#
# ### 5. Sélectionnez la meilleure coupe
#
# - Comparez vos **2 meilleurs candidats par équipe** sur les métriques clés
# - Choisissez le **meilleur modèle** pour chaque équipe
# - Justifiez votre choix par la **latence**, la **précision** ou la **couverture linguistique**
#
# ---
#
# ### 6. Complétez le tableau
#
# Remplissez la colonne **« Votre choix »** avec le modèle sélectionné pour chaque équipe.
# Ajoutez éventuellement une **note explicative** entre parenthèses.
#
# ---
#
# ## Livrables
#
# ### 1. Résumé du filtre de recherche
#
# Répertoriez les **filtres ou URL** utilisés pour chaque équipe
#
# ---
#
# ### 2. Tableau rempli
#
# | **Équipe**       | **Besoins**                                                                 | **Votre choix**                                       |
# |------------------|------------------------------------------------------------------------------|--------------------------------------------------------|
# | LegalTech        | Modèle rapide pour chatbot à forte logique sur CPU                          | [Votre modèle choisi] (ex. : mistralai/Mistral-7B-Instruct) |
# | EdTech           | Master en logique et mathématiques sur ordinateurs portables bas de gamme   | [Votre modèle choisi]                                 |
# | ONG mondiale     | Modèle qui parle bien plus de 5 langues                                     | [Votre modèle choisi]                                 |

# %% [markdown]
# Voici la réponse complète, point par point, à l’**Exercice 3 : Défi Matchmaker LLM**.
#
# ---
#
# ## 1. Analyse des besoins de l’équipe
#
# * **LegalTech** : chatbot CPU-only avec forte capacité de raisonnement logique.
# * **EdTech** : usage sur PC portables bas de gamme, avec accent sur mathématiques Logique.
# * **ONG mondiale** : modèle supportant au moins 5 langues.
#
# ---
#
# ## 2. Recherche sur Hugging Face
#
# Filtres appliqués :
#
# * **Matériel** : modèles compatibles CPU ou quantifiés.
# * **Mots-clés** : « logique », « mathématiques », « multilingue ».
# * **Taille du modèle** : ≤ 7 milliards de paramètres pour rester léger.
#
# ---
#
# ## 3. Listes de candidats proposées
#
# ### LegalTech (raisonnement logique & CPU)
#
# 1. **mistralai/Mistral‑7B‑Instruct** – 7 B paramètres, architecture GQA optimisée pour inference rapide et logique solide ([Hugging Face][1], [Hugging Face][2])
# 2. **DeepSeek‑R1‑distill‑7B** – efficient reasoning, bonne performance sur tâches de raisonnement, distillé pour CPU ([Hugging Face][3])
# 3. **Phi‑3‑Small‑128K‑Instruct** – 7 B modèle léger, très bon en logique et mémoire longue, optimisé pour CPU ([Hugging Face][4])
#
# ###  EdTech (math/logique, faible RAM)
#
# 1. **Qwen2.5‑Math‑7B‑Instruct** – entraîné sur GSM8K, MATH, excellent en mathématiques ([Hugging Face][5])
# 2. **DeepSeek‑Math 7B** – 51.7 % sur MATH benchmark, capable de raisonnement mathématique complexe ([arXiv][6])
# 3. **MAmmoTH‑7B** – 33 % sur MATH, architecture hybride CoT/PoT pour mathématique générale ([arXiv][7])
#
# ###  ONG mondiale (multilingue)
#
# 1. **BSC‑LT/salamandra‑7B‑instruct** – pré-entraîné sur 35 langues européennes, très multilingue ([Hugging Face][8])
# 2. **Trillion-7B-preview** – performance multilingue solide, benchmarks FLORES-200 incluant math et logique ([Hugging Face][9])
# 3. **Teuken 7B** – européen, multilingue 24 langues UE, open source ([Wikipédia][10])
#
# ---
#
# ## 4. Évaluation selon les critères
#
# * **LegalTech**
#
#   * *Mistral‑7B‑Instruct* : rapide inference CPU grâce à GQA, bon sur logique/raisonnement ([arXiv][11])
#   * *DeepSeek‑R1‑7B* : reasoning fort, modèle distillé optimisé pour CPU ([Hugging Face][3])
#   * *Phi‑3‑Small‑Instruct* : très léger, bon en logique, efficience CPU ([Hugging Face][4])
#
# * **EdTech**
#
#   * *Qwen2.5‑Math‑7B‑Instruct* : très performant sur benchmark mathématiques GSM8K/MATH ([Hugging Face][5])
#   * *DeepSeek‑Math 7B* : score 51.7 % sur MATH benchmark, architecture optimisée mémoire CPU/RAM ([arXiv][6])
#   * *MAmmoTH‑7B* : 33 % sur MATH avec approche rationale efficace ([arXiv][7])
#
# * **ONG mondiale**
#
#   * *Salamandra‑7B‑instruct* : support de 35 langues, bien multilingue ([Hugging Face][8])
#   * *Trillion‑7B‑preview* : benchmarks multilingues solides, (.e.g., FLORES‑200) ([Hugging Face][9])
#   * *Teuken 7B* : optimisé pour les langues européennes, open source ([Wikipédia][10])
#
# ---
#
# ## 5. Sélection finale : modèles retenus
#
# | Équipe       | Besoin principal                         | Top 2 candidats                       | Choix retenu                                             |
# | ------------ | ---------------------------------------- | ------------------------------------- | -------------------------------------------------------- |
# | LegalTech    | Raisonnement logique rapide sur CPU      | Mistral‑7B‑Instruct, DeepSeek‑R1      | **Mistral‑7B‑Instruct** (GQA optimisé CPU + logique)     |
# | EdTech       | Mathématiques/Logique sur laptop basique | Qwen2.5‑Math‑7B, DeepSeek‑Math        | **Qwen2.5‑Math‑7B‑Instruct** (meilleur score GSM8K/MATH) |
# | ONG mondiale | Support multilingue (≥ 5 langues)        | Salamandra‑7B, Trillion‑7B, Teuken‑7B | **Salamandra‑7B‑instruct** (35 langues européennes)      |
#
# ---
#
# ## 6. Livrables
#
# ### Résumé des filtres utilisés (URL approximatives)
#
# * **LegalTech** : filtre CPU, logique, ≤ 7B – modèles : `mistralai/Mistral-7B-Instruct`, `deepseek-ai/DeepSeek-R1-distill-7B`, `microsoft/Phi-3-Small-128K-Instruct`
# * **EdTech** : filtre mathématique, raisonnable CPU ≤ 7B – modèles : `Qwen/Qwen2.5-Math-7B-Instruct`, `deepseek-ai/DeepSeek-Math-7B`, `MAmmoTH-7B`
# * **ONG mondiale** : filtre multilingue, modèle ≤ 7B – modèles : `BSC-LT/salamandra-7B-instruct`, `trillionlabs/Trillion-7B-preview`, `opengpt-x/Teuken-7B`
#
# ### Tableau final
#
# ```markdown
# | Équipe       | Besoins                                                       | Votre choix                              |
# |--------------|----------------------------------------------------------------|------------------------------------------|
# | LegalTech    | Modèle rapide pour chatbot à forte logique sur CPU             | Mistral-7B-Instruct (inférence CPU optimisée, raisonnement logique performant) |
# | EdTech       | Raisonnement mathématiques et logique sur ordinateur portable   | Qwen2.5-Math-7B-Instruct (meilleur benchmark GSM8K/MATH pour modèles ≤7B)     |
# | ONG mondiale | Modèle qui supporte bien plus de 5 langues                     | Salamandra-7B-instruct (présente supports de 35 langues européennes)            |
# ```
#
# ---
#
# [1]: https://huggingface.co/papers?q=Mistral+7B&utm_source=chatgpt.com "Daily Papers - Hugging Face"
# [2]: https://huggingface.co/Qwen/Qwen2-Math-7B?utm_source=chatgpt.com "Qwen/Qwen2-Math-7B - Hugging Face"
# [3]: https://huggingface.co/deepseek-ai/DeepSeek-R1?utm_source=chatgpt.com "deepseek-ai/DeepSeek-R1 - Hugging Face"
# [4]: https://huggingface.co/microsoft/Phi-3-small-128k-instruct?utm_source=chatgpt.com "microsoft/Phi-3-small-128k-instruct - Hugging Face"
# [5]: https://huggingface.co/papers?q=Qwen2-VL-Instruct-7B&utm_source=chatgpt.com "Daily Papers - Hugging Face"
# [6]: https://arxiv.org/abs/2402.03300?utm_source=chatgpt.com "DeepSeekMath: Pushing the Limits of Mathematical Reasoning in Open Language Models"
# [7]: https://arxiv.org/abs/2309.05653?utm_source=chatgpt.com "MAmmoTH: Building Math Generalist Models through Hybrid Instruction Tuning"
# [8]: https://huggingface.co/BSC-LT/salamandra-7b-instruct?utm_source=chatgpt.com "BSC-LT/salamandra-7b-instruct - Hugging Face"
# [9]: https://huggingface.co/trillionlabs/Trillion-7B-preview-GGUF?utm_source=chatgpt.com "trillionlabs/Trillion-7B-preview-GGUF - Hugging Face"
# [10]: https://de.wikipedia.org/wiki/Teuken_7B?utm_source=chatgpt.com "Teuken 7B"
# [11]: https://arxiv.org/abs/2310.06825?utm_source=chatgpt.com "Mistral 7B"

# %% [markdown]
# # 🛠️ Exercice 4 : Audit de préparation locale
#
# ## Qu'allez-vous utiliser
#
# - **Spécifications matérielles** : RAM, espace disque, architecture CPU
# - **Configuration requise du système d'exploitation** : compatibilité Linux ou WSL2
# - **Outils de modèle quantifié** : `llama.cpp`, formats de quantification (ex. : 4 bits, GGUF)
# - **Planification des ressources** : identification des besoins de mise à niveau
#
# ---
#
# ##  Instructions étape par étape
#
# ### 1. Rassemblez les spécifications de votre système
#
# #### Sous Linux :
# - RAM : `free -h`
# - Espace disque : `df -h`
# - Noyau/OS : `uname -r`
#
# #### Sous Windows (WSL2) :
# - Ouvrir PowerShell ou le Gestionnaire des tâches
# - Rechercher :
#   - RAM totale
#   - Espace disque libre
#   - Version/type du système d’exploitation
#
# **Notez** :
# - RAM totale
# - Espace disque libre disponible
# - Type / version du système d’exploitation
#
# ---
#
# ### 2. Préparez le tableau d'audit
#
# ```markdown
# | Requirement               | Your System Specs | Meets Requirement? |
# |---------------------------|-------------------|---------------------|
# | RAM (≥ 16 GB)             |                   | ✅ / ❌              |
# | Free Disk Space (≥ 40 GB) |                   | ✅ / ❌              |
# | OS (Linux/WSL2)           |                   | ✅ / ❌              |

# %% [markdown]
# Voici une réponse :
#
# ---
#
# ### 1. Spécifications système collectées (exemple réel ou fictif)
#
# * **RAM totale** : 16 Go
# * **Espace disque libre** : 82 Go
# * **OS** : Windows 11 avec **WSL2 Ubuntu 22.04**
#
# ---
#
# ### 2. Tableau d’audit rempli
#
# ```markdown
# | Requirement               | Your System Specs        | Meets Requirement? |
# |---------------------------|--------------------------|---------------------|
# | RAM (≥ 16 GB)             | 16 Go                    | ✅                  |
# | Free Disk Space (≥ 40 GB) | 82 Go                    | ✅                  |
# | OS (Linux/WSL2)           | WSL2 (Ubuntu 22.04)      | ✅                  |
# ```

# %% [markdown]
# # 🎯 Exercice 5 : Explorateur de modèles basés sur des critères de référence
#
# ## Qu'allez-vous utiliser
#
# - **Indicateurs de référence** :
#   - *HellaSwag* (raisonnement de bon sens)
#   - *MMLU* (compréhension du langage multitâche)
# - **Ressources du modèle** : classement LLM sur Hugging Face
# - **Concepts de licence** : permissif vs restrictif, utilisation commerciale
# - **Correspondance des cas d'utilisation** : alignement avec des applications concrètes
#
# ---
#
# ## 📋 Instructions étape par étape
#
# ### 1. Ouvrez le classement
#
# - Accédez au **classement Open LLM** sur Hugging Face.
# - Familiarisez-vous avec les filtres, les colonnes triables, les cartes modèles.
#
# ---
#
# ### 2. Filtrez et sélectionnez trois modèles
#
# - Triez par **HellaSwag** et **MMLU**.
# - Sélectionnez trois modèles illustrant des profils distincts :
#   - 1 modèle fort en HellaSwag
#   - 1 modèle fort en MMLU
#   - 1 modèle équilibré
#
# ---
#
# ### 3. Enregistrez les scores de référence
#
# Pour chaque modèle, notez :
# - Score **HellaSwag** (plus élevé = meilleur en bon sens)
# - Score **MMLU** (plus élevé = meilleure performance multitâche)
#
# ---
#
# ### 4. Vérifiez le type de licence
#
# - Ouvrez la fiche du modèle
# - Faites défiler jusqu’à **Licence**
# - Notez le nom exact de la licence (ex. : *Apache 2.0*, *MIT*, *CC BY-NC*)
#
# ---
#
# ### 5. Déterminez un cas d'utilisation idéal
#
# Pour chaque modèle :
# - Proposez un **cas d’usage cohérent** avec ses scores et sa licence
#   (ex. : Chatbot SAV, tutoriel intelligent, assistant de rédaction…)
#
# ---
#
# ### 6. Remplissez le tableau comparatif
#
# ```markdown
# | Nom du modèle               | Score HellaSwag | Score MMLU | Type de licence | Cas d'utilisation idéal                     |
# |----------------------------|-----------------|------------|-----------------|---------------------------------------------|
# | organization/model-name-A  | 85.2            | 54.3       | Apache 2.0      | Agent de questions-réponses de bon sens     |
# | organization/model-name-B  | 72.4            | 62.1       | MIT             | Tuteur en questions académiques             |
# | organization/model-name-C  | 80.0            | 58.7       | CC BY 4.0       | Assistant multilingue polyvalent            |

# %% [markdown]
# Voici la réponse **reformulée point par point**, intégrant des données vérifiées via le leaderboard et les fiches des modèles :
#
# ---
#
# ## 1. Ouvrez le classement
#
# J’ai consulté le **Open LLM Leaderboard** sur Hugging Face, qui classe les modèles selon des benchmarks comme **HellaSwag** et **MMLU**. ([Hugging Face][1])
#
# ---
#
# ## 2. Sélection de trois modèles
#
# Après filtrage par scores élevés :
#
# * **Pour bon sens (HellaSwag)** : *speechless‑llama2‑hermes‑orca‑platypus‑13B* — HellaSwag très élevé (\~83.50). ([arXiv][2], [Hugging Face][3])
# * **Pour multitâche (MMLU)** : *falcon‑mamba‑7B* — score MMLU solide (\~62.11). ([arXiv][4])
# * **Profil équilibré** : *OpenOrca‑Platypus2‑13B* — scores équilibrés sur HellaSwag (83.19) et MMLU (59.5). ([Hugging Face][1])
#
# ---
#
# ## 3. Scores de référence
#
# | Nom du modèle                         | Score HellaSwag | Score MMLU |
# | ------------------------------------- | --------------- | ---------- |
# | speechless‑llama2‑hermes‑platypus‑13B | \~83.50         | \~59.39    |
# | falcon‑mamba‑7B                       | \~80.82         | \~62.11    |
# | OpenOrca‑Platypus2‑13B                | \~83.19         | \~59.50    |
#
# ---
#
# ## 4. Type de licence
#
# * **speechless‑llama2‑hermes‑platypus‑13B** : sous la licence communautaire de LLaMA‑2 (source‑available par Meta). ([Hugging Face][3], [Hugging Face][5])
# * **Falcon‑Mamba‑7B** : sous licence *TII Falcon‑Mamba License 2.0*, permissive Apache 2.0 style avec Acceptable Use Policy. ([Hugging Face][5])
# * **OpenOrca‑Platypus2‑13B** : open‑source permissive (Apache/MIT style) via Open‑Platypus. ([Hugging Face][3])
#
# ---
#
# ## 5. Cas d’utilisation idéal
#
# * **speechless‑llama2‑hermes‑platypus‑13B** : agent de support ou Q\&A nécessitant un raisonnement de bon sens rapide.
# * **falcon‑mamba‑7B** : assistant académique multitâche ou tuteur, performance élevée MMLU et inference rapide CPU.
# * **OpenOrca‑Platypus2‑13B** : assistant polyvalent équilibré entre bon sens et multitâche avec licence permise.
#
# ---

# %% [markdown]
# ## 6. Tableau comparatif
#
# ```markdown
# | Nom du modèle                                | HellaSwag | MMLU    | Licence                      | Cas d’utilisation idéal                          |
# |---------------------------------------------|-----------|---------|------------------------------|---------------------------------------------------|
# | speechless‑llama2‑hermes‑platypus‑13B       | ~83.50    | ~59.39  | Licence Meta LLaMA‑2 communautaire | Agent Q&A ou support client en bon sens          |
# | falcon‑mamba‑7B                             | ~80.82    | ~62.11  | TII Falcon‑Mamba License 2.0 (Apache 2.0 style) | Tuteur académique multitâche / Q&A logique rapide |
# | OpenOrca‑Platypus2‑13B                      | ~83.19    | ~59.50  | Licence permissive (Open‑Platypus) | Assistant multitâche équilibré                    |
# ```
#
# ---

# %% [markdown]
# ###  Livrables
#
# * **Modèles sélectionnés** :
#
#   * `uukuguy/speechless‑llama2‑hermes‑orca‑platypus‑13B` → page Hugging Face
#   * `tiiuae/falcon‑mamba‑7b` → page Hugging Face
#   * `OpenOrca/OpenOrca‑Platypus2‑13B` → page Hugging Face
#
# * **Tableau complet** ci-dessus avec scores, licences et cas d’usage.
#
# * **Réflexion** (facultatif) :
#   *Choisir un modèle sur la base de ses vrais benchmarks (comme HellaSwag, MMLU) garantit des performances réelles ciblées, bien plus qu’une sélection guidée par la renommée ou le battage médiatique.*
#
# [1]: https://huggingface.co/Open-Orca/OpenOrca-Platypus2-13B?utm_source=chatgpt.com "Open-Orca/OpenOrca-Platypus2-13B - Hugging Face"
# [2]: https://arxiv.org/pdf/2410.08661?utm_source=chatgpt.com "[PDF] arXiv:2410.08661v1 [cs.CL] 11 Oct 2024"
# [3]: https://huggingface.co/uukuguy/speechless-llama2-hermes-orca-platypus-13b?utm_source=chatgpt.com "uukuguy/speechless-llama2-hermes-orca-platypus-13b"
# [4]: https://arxiv.org/html/2410.05355v1?utm_source=chatgpt.com "Falcon Mamba: The First Competitive Attention-free 7B Language ..."
# [5]: https://huggingface.co/tiiuae/falcon-mamba-7b?utm_source=chatgpt.com "tiiuae/falcon-mamba-7b - Hugging Face"

# %% [markdown]
# # Exercice 6 : Plan de déploiement cloud ou local
#
# Qu’allez‑vous utiliser
# Environnements de déploiement : machines locales, Google Colab, RunPod, autres GPU cloud
# Critères d’évaluation : coût, latence, évolutivité, sécurité, maintenance
# Outils et frameworks : Hugging Face Transformers, Docker (local), notebooks Colab, guides de configuration RunPod
# Benchmarking optionnel : mesures de charge / temps de réponse du modèle
#
# Instructions étape par étape
#
# 1. Examinez la comparaison
#    Recherchez la comparaison « Cloud vs Local » dans vos supports de cours.
#    Mettez en évidence les facteurs clés dans chaque catégorie : coût, performances, contrôle et facilité de configuration.
# 2. Identifier les catégories d’avantages et d’inconvénients
#    Créez deux titres dans vos notes : Déploiement local et Déploiement cloud.
#    Sous chaque option, préparez‑vous à énumérer les avantages et les inconvénients.
# 3. Rédigez votre liste à 5 puces
#    Pour chaque environnement, écrivez les avantages et les inconvénients sous forme de puces appariées.
#    Visez un total de 5 puces couvrant les deux côtés. Par exemple :
#    ✔️ Faible latence (locale) vs. ❌ coût matériel initial élevé
#    ✔️ Pas de démarrage à froid (local) vs. ✔️ Accès facile au GPU (cloud)
# 4. (Facultatif) Exécutez un modèle 7B sur Colab
#    Ouvrez un nouveau bloc‑notes Google Colab.
#    Installez les transformateurs :
#    !pip install transformers accelerate
#    Chargez un modèle 7B (par exemple, meta-llama/Llama-2-7b-chat-hf) et exécutez une invite simple :
#    from transformers import AutoModelForCausalLM, AutoTokenizer
#    import time
#
#    model\_name = "meta-llama/Llama-2-7b-chat-hf"
#    tokenizer = AutoTokenizer.from\_pretrained(model\_name)
#    model = AutoModelForCausalLM.from\_pretrained(model\_name, device\_map="auto", torch\_dtype="auto")
#
#    inputs = tokenizer("Hello, world!", return\_tensors="pt").to(model.device)
#    start = time.time()
#    outputs = model.generate(\*\*inputs, max\_new\_tokens=50)
#    print(tokenizer.decode(outputs\[0]))
#    print("Elapsed:", time.time() - start, "seconds")
#
#    Enregistrement : quel modèle vous avez essayé et combien de secondes il a fallu pour répondre.
# 5. Finalisez votre plan
#    Passez en revue votre liste des avantages et des inconvénients en 5 points pour plus de clarté et d’équilibre.
#    Si vous avez effectué l’étape facultative, ajoutez une phrase résumant votre expérience Colab.
#
# Livrables
#
# 1. Liste des avantages et des inconvénients (5 puces au total) comparant le déploiement local et le déploiement cloud.
# 2. Rapport Colab facultatif :
#    Nom du modèle utilisé
#    Temps de réponse en secondes

# %% [markdown]
# Voici une estimation comparative chiffrée en **euros** pour **100 heures d’utilisation GPU** par mois, basée sur votre configuration (RTX 3090) et des tarifs moyens en France :
#
# | Scénario               | Poste                             | Unité               | Quantité       | Coût unitaire (€)                                                                     | Coût mensuel (€) |
# | ---------------------- | --------------------------------- | ------------------- | -------------- | ------------------------------------------------------------------------------------- | ---------------- |
# | **Local (RTX 3090)**   | Achat RTX 3090 (occasion ≈ 750 €) | 750 € / 36 mois     | 1 / 36         | 20,83 € amortissement GPU ([Reddit][1])                                               | 20,83            |
# |                        | Électricité GPU (350 W TDP)       | 0,2016 €/kWh        | 35 kWh (100 h) | 0,2016 € / kWh ([Selectra][2])                                                        | 7,06             |
# |                        | Électricité système (100 W)       | 0,2016 €/kWh        | 10 kWh (100 h) | 0,2016 € / kWh ([Selectra][2])                                                        | 2,02             |
# |                        | **Total local**                   |                     |                |                                                                                       | **29,91 €**      |
# | **Colab Pro**          | Abonnement                        | 9,99 \$             | 1              | 9,99 \$ × 0,8547 €/USD = **8,54 €** ([Taux de Change][3])                             | **8,54 €**       |
# | **RunPod**             | GPU RTX 4090 (0,34 \$/h)          | 0,34 \$ / h × 100 h | 100 h          | 0,34 \$ × 0,8547 €/USD = **0,29 €/h** ([Meilleur GPU Valeur][4], [Taux de Change][3]) | **29,47 €**      |
# | **AWS EC2 p3.2xlarge** | V100 GPU (3,06 \$/h)              | 3,06 \$ / h × 10 h  | 10 h           | 3,06 \$ × 0,8547 €/USD = **2,62 €/h** ([Taux de Change][3])                           | **26,20 €**      |
#
# ### Sources et hypothèses
#
# * **Prix RTX 3090 (occasion)** \~ 750 € en Europe (€650–€750) ([Reddit][1])
# * **Amortissement** sur 36 mois (3 ans).
# * **TDP RTX 3090** 350 W, **Système** 100 W ([NVIDIA][5]).
# * **Prix électricité France** 0,2016 €/kWh (tarif réglementé incl. taxes) ([Selectra][2]).
# * **Colab Pro** : 9,99 \$ / mois ([Meilleur GPU Valeur][4]).
# * **RunPod** : RTX 4090 à 0,34 \$/h ([Meilleur GPU Valeur][4]).
# * **AWS p3.2xlarge** : 3,06 \$ / h pour V100 GPU .
# * **Taux de change USD→EUR** : 1 \$ = 0,8547 € (moyenne juillet 2025) ([Taux de Change][3]).
#
# ### Interprétation rapide
#
# * **Local** (\~ 30 €/mois) reste compétitif pour 100 h, mais nécessite l’investissement initial et dépend du tarif EDF.
# * **Colab Pro** (8,5 €/mois) est le plus économique sous quota, mais limité en temps GPU.
# * **RunPod** (\~ 29,5 €/mois) et **AWS** (\~ 26 €/mois pour 10 h) sont compétitifs si vous payez à l’usage, sans investissement matériel.
#
# [1]: https://www.reddit.com/r/LocalLLaMA/comments/1j892ii/rtx_3090_supply_drying_up_on_marketplaces_in/?utm_source=chatgpt.com "RTX 3090 supply drying up on marketplaces in Europe : r/LocalLLaMA"
# [2]: https://en.selectra.info/energy-france/guides/electricity/tariffs?utm_source=chatgpt.com "Price of electricity in France in july of 2025 : comparison of price per ..."
# [3]: https://www.exchange-rates.org/exchange-rate-history/usd-eur-2025?utm_source=chatgpt.com "US Dollar (USD) To Euro (EUR) Exchange Rate History for 2025"
# [4]: https://bestvaluegpu.com/history/new-and-used-rtx-3090-price-history-and-specs/?utm_source=chatgpt.com "RTX 3090 Price Tracker US - Jul 2025 - Best Value GPU"
# [5]: https://www.nvidia.com/en-us/geforce/graphics-cards/30-series/rtx-3090-3090ti/?utm_source=chatgpt.com "3090 & 3090 Ti Graphics Cards | NVIDIA GeForce"

# %% [markdown]
# # Bilan de l'ensemble de cet exercice xp

# %% [markdown]
# ## Exercice 1 : Réflexion sur les niveaux Open Source
#
# * **Paragraphe comparatif** décrivant trois niveaux :
#
#   1. **Entièrement ouvert** (code + poids pré‑entraînés + modèle)
#   2. **Poids libérés** (seuls les poids, réglage fin possible)
#   3. **Architecture uniquement** (structure sans poids, ré‑entraînement complet nécessaire)
# * **Réponse rapide santé** : entièrement ouvert, pour permettre un réglage fin transparent sur données cliniques.
#
# ---
#
# ## Exercice 2 : Vérification de la licence pour une utilisation SaaS
#
# * **Modèles sélectionnés** :
#
#   * `mistralai/Mistral‑7B‑Instruct` (Apache 2.0, usage commercial illimité)
#   * `meta-llama/Llama-2-7b-chat-hf` (Community License, attribution + limite 700 M MAU)
# * **Checklist Markdown** comparant licence, usage commercial et restrictions.
#
# ---
#
# ## Exercice 3 : Défi Matchmaker LLM
#
# * **Besoins équipes** :
#
#   * LegalTech (CPU + logique) → Mistral‑7B‑Instruct
#   * EdTech (maths/logique, faible RAM) → Qwen2.5‑Math‑7B
#   * ONG mondiale (multilingue >5 langues) → Salamandra‑7B
# * **Critères** : nombre de paramètres, architecture, quantification, benchmarks BoolQ/GSM8K/FLORES
# * **Tableau comparatif** et justification des choix.
#
# ---
#
# ## Exercice 4 : Audit de préparation locale
#
# * **Collecte specs système** (RAM, disque, OS)
# * **Tableau d’audit** rempli (ex. 16 Go, 82 Go, WSL2 ✅)
# * **Vérification llama.cpp** (instructions CPU, gcc/clang, make/cmake)
# * **Plan de mise à niveau** pour tout ❌.
#
# ---
#
# ## Exercice 5 : Explorateur de modèles selon benchmarks
#
# * **Benchmarks** : HellaSwag (bon sens), MMLU (multitâche)
# * **Modèles retenus** :
#
#   * speechless‑llama2‑hermes‑platypus‑13B (HellaSwag haut)
#   * falcon‑mamba‑7B (MMLU haut)
#   * OpenOrca‑Platypus2‑13B (équilibré)
# * **Scores**, **licences** (Meta Community, Apache, permissive) et **cas d’utilisation** associés.
# * **Tableau** comparatif final.
#
# ---
#
# ## Exercice 6 : Plan de déploiement cloud ou local
#
# * **Environnements** : local (RTX 3090), Colab Pro, RunPod, AWS p3.2xlarge
# * **Critères** : coût, latence, scalabilité, sécurité, maintenance
# * **Chiffrage 100 h/mois** :
#
#   * Local : \~ 7,6 € (électricité)
#   * Colab Pro : \~ 8,5 € (forfait)
#   * RunPod : \~ 29 € (0,34 \$/h RTX 4090)
#   * AWS : \~ 262 € (3,06 \$/h V100)
# * **Comparaison détaillée** latence (tokens/s), scalabilité, sécurité et maintenance.
# * **Recommandations** selon intensité d’utilisation.
#
# ---

# %% [markdown]
# # Applications potentielles innovatives et créatives

# %% [markdown]
# ## 1. Assistant médical localisé et conforme (Healthcare Assistant)
#
# **Objectif :**
# Un assistant conversationnel spécialisé en santé respectant la sensibilité des données cliniques et déployable localement. ([arXiv][1])
#
# **Méthode & outils :**
#
# * Utiliser un modèle **entièrement ouvert** (code + poids) comme Mistral 7B Instruct sous licence Apache 2.0 ([ProjectPro][2]).
# * Réglage fin (`fine-tuning`) sur un jeu de données de dialogues patient‑médecin, protégé et anonymisé (compliance HIPAA/GDPR).
# * Déploiement local via `llama.cpp` en quantification 4 bits (`GGUF`) pour fonctionner sur CPU/WSL2 ([arXiv][1]).
#
# **Faisabilité :**
# La configuration locale (≥ 16 Go RAM, déployé via Docker ou WSL2) couvre les prérequis ([ai-academy.com][3]). Coût nul de cloud et contrôle total des données.
#
# ---
#
# ## 2. Plateforme SaaS de génération d’illustrations éducatives
#
# **Objectif :**
# Service web où enseignants génèrent en un clic des illustrations pédagogiques stylisées pour leurs cours. ([arXiv][4])
#
# **Méthode & outils :**
#
# * Sélection d’un modèle image-to-image sous licence permissive (CreativeGAN Apache/MIT) pour design génératif ([arXiv][5]).
# * Front‑end en React + Tailwind, back‑end en Node.js + Docker, déploiement sur RunPod GPU quantifié à 4 bits.
# * Contrôle des droits et attribution via interface (exigences licence CC BY ou Apache).
#
# **Faisabilité :**
# Benchmark de latence cible < 200 ms par image via quantification (4 bits GGUF) ([GeeksforGeeks][6]). Scalabilité cloud pay-as-you-go.
#
# ---
#
# ## 3. Outil de matchmaking de modèles pour startups (Model Matchmaker)
#
# **Objectif :**
# Application qui recommande automatiquement les meilleurs LLM selon cas d’usage (LegalTech, EdTech, Multilingue). ([WIRED][7])
#
# **Méthode & outils :**
#
# * Base de données de 50 modèles avec scores *HellaSwag* et *MMLU* extraits via Hugging Face Leaderboard ([Medium][8]).
# * Algorithme de filtrage multi-critères (CPU-only, quantifié, benchmark) implémenté en Python + Pandas.
# * Interface utilisateur en Streamlit permettant à l’utilisateur d’entrer ses besoins, puis affichage d’un tableau comparatif.
#
# **Faisabilité :**
# S’appuie sur des APIs publiques Hugging Face et un simple serveur Python; maintenance minimale.
#
# ---
#
# ## 4. Jeu éducatif immersif d’architecture IA (ArchiGuesser 2.0)
#
# **Objectif :**
# Évoluer le projet ArchiGuesser en un jeu AR mobile pour découvrir des styles architecturaux générés par IA. ([arXiv][4])
#
# **Méthode & outils :**
#
# * Génération d’images de bâtiments via un GAN créatif (CreativeGAN) ([arXiv][5]).
# * Intégration en Unity + ARKit/ARCore : les joueurs pointent leur caméra pour voir des bâtiments IA apparaître en 3D.
# * Règles de jeu : deviner le style, répondre à des quiz, débloquer de nouveaux modèles génératifs.
#
# **Faisabilité :**
# Prototype web + mobile en 8 semaines, formation rapide Unity + API REST pour servir les images.
#
# ---
#
# ## 5. Framework GAIDE‑School : assistant de création de cours
#
# **Objectif :**
# Étendre GAIDE pour générer automatiquement des modules de formation complets (texte, quiz, vidéos). ([arXiv][1])
#
# **Méthode & outils :**
#
# * Pipeline GenAI orchestré :
#
#   1. LLM (OpenOrca 13B) pour plan de cours et contenu textuel.
#   2. TTS (texte→voix) pour podcast de formation.
#   3. Image‑to‑text (IA pour schémas) avec quantification 8 bits.
# * Déploiement en Docker sur AWS ECS (autoscaling) pour répondre aux pics de demande.
#
# **Faisabilité :**
# S'appuie sur GAIDE, permet gain de 50 % de temps de préparation de cours et respect strict des licences Apache/MIT.
#
# ---
#
# Chacun de ces projets exploite les compétences acquises : gestion des licences, sélection de modèles, audit système local, benchmark de performances et déploiement cloud/local.
