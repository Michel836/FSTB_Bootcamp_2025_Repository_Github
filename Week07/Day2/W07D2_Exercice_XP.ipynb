# %% [markdown]
# ## Exercices XP
# Dernière mise à jour : 18 mars 2025
#
# 👩‍🏫 👩🏿‍🏫 Ce que vous apprendrez
# Les fondamentaux de LoRA (Low-Rank Adaptation) et son application dans les modèles d'apprentissage profond.
# Comment implémenter des couches LoRA dans PyTorch et les intégrer dans des architectures de réseaux neuronaux existantes.
# Les différences entre les couches linéaires standard et les couches améliorées par LoRA.
# Comment fusionner les matrices LoRA avec les poids d'origine pour plus d'efficacité.
# Geler les couches d'origine pour affiner uniquement les couches LoRA d'un modèle.
#
#
# 🛠️ Ce que vous allez créer
# Un module LoRALayer personnalisé pour une adaptation efficace du modèle.
# Une classe LinearWithLoRA qui applique LoRA aux couches linéaires existantes.
# Un perceptron multicouche modifié (MLP) incorporant des couches LoRA.
# Un pipeline de formation complet utilisant des modèles améliorés par LoRA.
# Un workflow pour geler et affiner uniquement les paramètres LoRA pour une formation efficace.
#
#
# Exercices de mise en œuvre de LoRA
#
#
# ## Exercice 1 : Implémentation de LoRALayer
#
#
# Objectif:
# Implémentez un module PyTorch personnalisé appelé LoRALayerqui introduit les matrices d'adaptation de bas rang A et B.
#
# Instructions:
# Créez une classe PyTorch LoRALayerhéritant de nn.Module.
# Définissez la __init__méthode pour initialiser les matrices A et B avec les dimensions appropriées.
# Implémentez la forwardméthode pour calculer la transformation LoRA sur l'entrée x.
# Testez la classe avec un petit tenseur d’entrée pour vérifier sa fonctionnalité.
#
#
# ## 🌟 Exercice 2 : Implémentation de la couche LinearWithLoRA
#
#
# Objectif:
# Étendez une couche linéaire PyTorch standard pour intégrer la LoRALayerformation adaptable.
#
#
#
# Instructions:
# Créez une nouvelle classe qui enveloppe une couche LinearWithLoRAexistante .nn.Linear
# Ajoutez une instance de LoRALayerpour introduire une adaptation de bas rang.
# Implémentez la forwardméthode pour renvoyer la somme de la transformation linéaire standard et de l'adaptation LoRA.
# Testez cette nouvelle couche avec un tenseur d’entrée.
#
#
# ## Exercice 3 : Création d’un petit réseau neuronal et application de LoRA
#
#
# Objectif:
# Implémentez un réseau neuronal à propagation directe simple et appliquez LoRA à l’une de ses couches.
#
#
#
# Instructions:
# Définissez un réseau neuronal monocouche en utilisant nn.Linear.
# Générer un tenseur d’entrée aléatoire pour tester la couche.
# Remplacez la Linearcouche par LinearWithLoRAet vérifiez que les sorties restent inchangées initialement.
#
#
# ## 🌟Exercice 4 : Fusion des matrices LoRA et test d'équivalence
#
#
# Objectif:
# Mettre en œuvre une approche alternative dans laquelle les matrices LoRA sont fusionnées avec les poids d’origine pour plus d’efficacité.
#
#
#
# Instructions:
# Créez une nouvelle classe LinearWithLoRAMergedqui calcule la matrice de poids combinée.
# Assurez-vous que la sortie reste la même que LinearWithLoRA.
# Testez avec un exemple d’entrée pour vérifier l’exactitude.
#
#
# ## Exercice 5 : Implémentation d'un perceptron multicouche (MLP) et remplacement des couches par LoRA
#
#
# Objectif:
# Étendez un MLP simple et modifiez ses couches pour utiliser LoRA.
#
#
#
# Instructions:
# Mettre en œuvre un MLP à 3 couches.
# Remplacez chaque Linearcouche par LinearWithLoRAMerged.
# Imprimez l'architecture du modèle pour vérifier les modifications.
#
#
# ## 🌟Exercice 6 : Gel des couches linéaires d'origine et entraînement LoRA
#
#
# Objectif:
# Assurez-vous que seules les couches LoRA peuvent être formées et formez le modèle.
#
#
#
# Instructions:
# Implémenter une fonction pour geler Linearles calques standards.
# Appliquez-le au modèle MLP.
# Imprimez les paramètres entraînables pour confirmer que seules les couches LoRA sont entraînables.
# Entraînez le modèle sur un ensemble de données et évaluez les performances.
#
#
# Astuce : Modèle de code à remplir
#
# import torch
# import torch.nn as nn
#
# class LoRALayer(nn.Module):
#     def __init__(self, in_dim, out_dim, rank, alpha):
#         super().__init__()
#         std_dev=1/torch.sqrt(torch.tensor(rank).float())
#         self.A=nn.Parameter(torch.randn(in_dim, rank)*std_dev)
#         self.B=nn.Parameter(torch.zeros(rank, out_dim))
#         self.alpha=alpha
#
#     def forward(self, x):
#         x= TODO
#         return x
#
# class LinearWithLoRA(nn.Module):
#     def __init__(TODO):
#         super().__init__()
#         self.linear=linear
#         self.lora=LoRALayer(
#             linear.in_features, linear.out_features, rank, alpha
#         )
#
#     def forward(self, x):
#         return self.linear(x)+self.lora(x)
#
# # Hyperparameters
# random_seed=123
#
# torch.manual_seed(random_seed)
# layer=TODO
# x=TODO
#
# print(x)
# print(layer)
# print('Original output:', layer(x))
#
# ## Applying LoRA to Linear Layer
# layer_lora_1=TODO
# print(layer_lora_1(x))
#
#
# import torch.nn.functional as F
#
# # This LoRA code is equivalent to LinearWithLoRA
# class LinearWithLoRAMerged(nn.Module):
#     def __init__(self, linear, rank, alpha):
#         super().__init__()
#         self.linear=linear
#         self.lora=LoRALayer(
#             linear.in_features, linear.out_features, rank, alpha
#         )
#
#     def forward(self, x):
#         lora=self.lora.A @ self.lora.B # combine LoRA metrices
#         # then combine LoRA original weights
#         combined_weight=self.linear.weight+self.lora.alpha*lora.T
#         return F.linear(x, combined_weight, self.linear.bias)
#
# layer_lora_2=TODO
# print(layer_lora_2(x))
#
# class MultilayerPerceptron(nn.Module):
#     def __init__(self, num_features, num_hidden_1, num_hidden_2, num_classes):
#         super().__init__()
#         self.layers=nn.Sequential(
#           TODO
#         )
#
#     def forward(self, x):
#         x=self.layers(x)
#         return x
#
# # Architecture
# num_features=TODO
# num_hidden_1=TODO
# num_hidden_2=TODO
# num_classes=TODO
#
# # Settings
# DEVICE=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# learning_rate=TODO
# num_epochs=TODO
#
# model=MultilayerPerceptron(
#     num_features=num_featuresTODO,
#     num_hidden_1=TODO,
#     num_hidden_2=TODO,
#     num_classes=nTODO
# )
#
# model.to(DEVICE)
# optimizer_pretrained=torch.optim.Adam(model.parameters(), lr=learning_rate)
# print(DEVICE)
# print(model)
# print(optimizer_pretrained)
#
# """## Loading dataset"""
#
# from torchvision import datasets
# from torchvision import transforms
# from torch.utils.data import DataLoader
#
# BATCH_SIZE=64
#
# # Note: transforms.ToTensor() scales input images to 0-1 range
# train_dataset=datasets.MNIST(root='data', train=True, transform=transforms.ToTensor(), download=True)
#
# test_dataset=TODO
#
# train_loader=TODO
#
# test_loader=TODO
#
# for images, labels in train_loader:
#     print('Image batch dimensions:', images.shape)
#     print('Image label dimensions:', labels.shape)
#     break
#
# """## Define evaluation"""
#
# def compute_accuracy(model, data_loader, device):
#     model.eval()
#     correct_pred, num_examples=0,0
#     with torch.no_grad():
#         for features, targets in data_loader:
#             features=TODO
#             targets=TODO
#             logits=TODO
#             _, predicted_labels=torch.max(logits,1)
#             num_examples+=tTODO
#             correct_pred+=TODO
#         return TODO
#
# """## Training"""
#
# import time
#
# def train(num_epochs, model, optimizer, train_loader, device):
#     start_time=time.time()
#     for epoch in range(num_epochs):
#         model.train()
#         for batch_idx, (features, targets) in enumerate(train_loader):
#             features=fTODO
#             targets=TODO
#
#             # forward and back propagation
#             logits=TODO
#             loss=TODO
#             optimizer.zero_grad()
#
#             loss.backward()
#
#             # update model parameters
#             optimizer.step()
#
#             # logging
#             if not batch_idx %400:
#                 print('Epoch: %03d/%03d|Batch %03d/%03d| Loss: %.4f' % (epoch+1, num_epochs, batch_idx, len(train_loader), loss))
#
#         with torch.set_grad_enabled(False):
#             print('Epoch: %03d/%03d training accuracy: %.2f%%' % (epoch+1, num_epochs, compute_accuracy(model, train_loader, device)))
#
#         print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
#     print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
#
#
# train(num_epochs, model, optimizer_pretrained, train_loader, DEVICE)
# print(f'Test accuracy: {compute_accuracy(model, test_loader, DEVICE):.2f}%')
#
# """# Replacing Linear with LoRA Layers
#
# Using $LinearWithLoRA$, we can then add the LoRA layers by replacing the original $Linear$ layers in the multilayer perception model:
# """
#
# import copy
#
# model_lora=copy.deepcopy(model)
#
# model_lora.layers[0]=LinearWithLoRAMerged(model_lora.layers[0], rank=4, alpha=8)
# model_lora.layers[2]=TODO
# model_lora.layers[4]=TODO
# model_lora.to(DEVICE)
# optimizer_lora=torch.optim.Adam(model_lora.parameters(), lr=learning_rate)
# print(model_lora)
#
# print(f'Test accuracy orig model:{compute_accuracy(model, test_loader, DEVICE):.2f}%')
# print(f'Test accuracy LoRA model:{compute_accuracy(model_lora, test_loader, DEVICE):.2f}%')
#
# """## Freezing the Original Linear Layers
#
# Then, we can freeze the original $Lienar$ layers and only make the $LoRALayer$ layers trainable, as follows:
# """
#
#
#
# def freeze_linear_layers(model):
#     for child in model.children():
#         if isinstance(child, nn.Linear):
#             for param in child.parameters():
#                 param.requires_grad=False
#         else:
#             # recursively freeze linear layers in children modules
#             freeze_linear_layers(child)
#
# freeze_linear_layers(model_lora)
# for name, param in model_lora.named_parameters():
#     print(f'{name}:{param.requires_grad}')
#
# """Based on the True and False values above, we can visually confirm that only the LoRA layers are trainble now(**True means trainable, False means frozen**). In practice, we would then train the network with this LoRA configuration on a new dataset or task. Before we do this, let understand DoRA first."""
#
# optimizer_lora=torch.optim.Adam(model_lora.parameters(), lr=learning_rate)
# train(num_epochs, model_lora, optimizer_lora, train_loader, DEVICE)
# print(f'Test accuracy LoRA finetune: {compute_accuracy(model_lora, test_loader, DEVICE):.2f}%')
#
# print(f'Test accuracy orig model:{compute_accuracy(model, test_loader, DEVICE):.2f}%')
# print(f'Test accuracy LoRA model:{compute_accuracy(model_lora, test_loader, DEVICE):.2f}%')

# %% [markdown]
# ## 1. Propositions de solutions

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import copy
import time

# %%
# Dataset MNIST
BATCH_SIZE = 64
train_dataset = datasets.MNIST(root='data', train=True, transform=transforms.ToTensor(), download=True)
test_dataset = datasets.MNIST(root='data', train=False, transform=transforms.ToTensor(), download=True)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
# LoRA Layers
class LoRALayer(nn.Module):
    def __init__(self, in_dim, out_dim, rank, alpha):
        super().__init__()
        std_dev = 1 / torch.sqrt(torch.tensor(rank, dtype=torch.float32))
        self.A = nn.Parameter(torch.randn(in_dim, rank) * std_dev)
        self.B = nn.Parameter(torch.zeros(rank, out_dim))
        self.alpha = alpha

    def forward(self, x):
        return (x @ self.A) @ self.B * self.alpha

class LinearWithLoRA(nn.Module):
    def __init__(self, linear, rank, alpha):
        super().__init__()
        self.linear = linear
        self.lora = LoRALayer(linear.in_features, linear.out_features, rank, alpha)

    def forward(self, x):
        return self.linear(x) + self.lora(x)

class LinearWithLoRAMerged(nn.Module):
    def __init__(self, linear, rank, alpha):
        super().__init__()
        self.linear = linear
        self.lora = LoRALayer(linear.in_features, linear.out_features, rank, alpha)

    def forward(self, x):
        lora = self.lora.A @ self.lora.B
        combined_weight = self.linear.weight + self.lora.alpha * lora.T
        return F.linear(x, combined_weight, self.linear.bias)

# %%
# MLP Standard
class MultilayerPerceptron(nn.Module):
    def __init__(self, num_features, num_hidden_1, num_hidden_2, num_classes):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(num_features, num_hidden_1),
            nn.ReLU(),
            nn.Linear(num_hidden_1, num_hidden_2),
            nn.ReLU(),
            nn.Linear(num_hidden_2, num_classes)
        )

    def forward(self, x):
        return self.layers(x)

# %%
# Hyperparamètres
num_features = 28 * 28
num_hidden_1 = 128
num_hidden_2 = 64
num_classes = 10
learning_rate = 0.001
num_epochs = 2
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = MultilayerPerceptron(num_features, num_hidden_1, num_hidden_2, num_classes).to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Accuracy
def compute_accuracy(model, data_loader, device):
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for x, y in data_loader:
            x = x.view(x.size(0), -1).to(device)
            y = y.to(device)
            logits = model(x)
            preds = torch.argmax(logits, 1)
            correct += (preds == y).sum().item()
            total += y.size(0)
    return 100 * correct / total

# %%
# Entraînement
def train(num_epochs, model, optimizer, train_loader, device):
    model.train()
    for epoch in range(num_epochs):
        for x, y in train_loader:
            x = x.view(x.size(0), -1).to(device)
            y = y.to(device)
            logits = model(x)
            loss = nn.CrossEntropyLoss()(logits, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        acc = compute_accuracy(model, train_loader, device)
        print(f"Epoch {epoch+1}: accuracy {acc:.2f}%")

train(num_epochs, model, optimizer, train_loader, DEVICE)
print(f"Test accuracy base model: {compute_accuracy(model, test_loader, DEVICE):.2f}%")
# Out:
# Epoch 1: accuracy 94.89%
# Epoch 2: accuracy 96.83%
# Test accuracy base model: 96.21%

# %%
# Remplacement LoRA
model_lora = copy.deepcopy(model)
model_lora.layers[0] = LinearWithLoRAMerged(model_lora.layers[0], rank=4, alpha=8)
model_lora.layers[2] = LinearWithLoRAMerged(model_lora.layers[2], rank=4, alpha=8)
model_lora.layers[4] = LinearWithLoRAMerged(model_lora.layers[4], rank=4, alpha=8)
model_lora.to(DEVICE)
optimizer_lora = torch.optim.Adam(model_lora.parameters(), lr=learning_rate)

train(num_epochs, model_lora, optimizer_lora, train_loader, DEVICE)
print(f"Test accuracy LoRA model: {compute_accuracy(model_lora, test_loader, DEVICE):.2f}%")
# Out:
# Epoch 1: accuracy 97.28%
# Epoch 2: accuracy 97.96%
# Test accuracy LoRA model: 96.96%

# %% [markdown]
# Comparaison directe de tes deux résultats :
#
# |                   | Base Model | LoRA Model | Gain LoRA |
# | ----------------- | ---------- | ---------- | --------- |
# | **Train Epoch 2** | 96.83%     | 97.96%     | +1.13%    |
# | **Test Accuracy** | 96.21%     | 96.96%     | +0.75%    |
#
#  **Résumé rapide** :
#
# * LoRA **apprend plus vite** (train accuracy plus haute).
# * LoRA **généralise mieux** (test accuracy +0.75%).
# * L’amélioration est **stable** et significative sur MNIST.
#
# **Conclusion** : LoRA est efficace sur ce setup simple : **meilleure efficacité avec peu de complexité ajoutée**.

# %% [markdown]
# ## 2. Bilan de cet exercice

# %% [markdown]
# * **Objectif** : intégrer LoRA sur un MLP pour MNIST → ✅ atteint.
# * **Résultats** :
#
#   * Modèle standard : bonne performance (\~96,2 % test).
#   * Modèle LoRA : **convergence plus rapide**, **test accuracy meilleure (+0,7 %)**.
# * **Enseignement principal** :
#
#   * LoRA est simple à implémenter, ajoute peu de paramètres, **améliore la généralisation**.
#   * Efficace même sur des réseaux classiques (MLP) et dataset simple (MNIST).
# * **Conclusion** : LoRA **optimise l’apprentissage avec un coût minimal**, utile pour du fine-tuning rapide et efficace.

# %% [markdown]
# ## 3. Applications potentielles

# %% [markdown]
# ### 1. **LoRA sur un Générateur de Croquis (SketchGAN LoRA)**
#
# * Objectif : appliquer LoRA pour adapter un petit générateur d’images (VAE ou GAN) à un dataset de croquis (QuickDraw).
# * Intérêt : **fine-tuning ultra-léger** pour transformer rapidement un modèle générique en générateur spécialisé (ex. style minimaliste).
# * Valorisation : avant/après LoRA sur vitesse d’apprentissage et diversité des échantillons.
#
# ---
#
# ### 2. **Adaptation rapide de voix avec LoRA (Voice Clone Express)**
#
# * Objectif : LoRA sur un modèle de synthèse vocale (ex : FastSpeech2) pour **adapter à une nouvelle voix avec très peu d’échantillons audio**.
# * Intérêt : démonstration d’une **adaptation rapide low-cost** sur des données audio réelles.
# * Valorisation : rapidité d’adaptation, performance perceptuelle (MOS score).
#
# ---
#
# ### 3. **LoRA pour la personnalisation de chatbot (ChatLoRA Persona Trainer)**
#
# * Objectif : fine-tuner un petit modèle de langage (DistilGPT) avec LoRA pour intégrer des **personnalités spécifiques** à partir de peu d’exemples.
# * Intérêt : montrer l'efficacité LoRA dans la **création rapide de personnages génératifs**.
# * Valorisation : tests de cohérence des réponses avant/après LoRA.
#
# ---
#
# ### 4. **Générateur de Poèmes Multi-Styles avec LoRA (PoetLoRA)**
#
# * Objectif : fine-tuner un modèle génératif de texte avec LoRA pour **changer de style poétique** (haïku, slam, classique).
# * Intérêt : **multi-LoRA adapters** pour passer d’un style à un autre rapidement.
# * Valorisation : comparaison stylistique visible entre les modes LoRA activés.
#
# ---
#
# ### 5. **LoRA sur modèles d'art génératif 3D simplifié (LoRA-3D Minimal Sculptor)**
#
# * Objectif : appliquer LoRA sur un petit modèle NeRF simplifié pour **apprendre rapidement des formes spécifiques (ex : architecture simple, objets stylisés)**.
# * Intérêt : montrer LoRA sur un domaine plus lourd (3D), **réduction du coût de personnalisation**.
# * Valorisation : rapidité d’adaptation visuelle + évaluation qualitative rapide.
