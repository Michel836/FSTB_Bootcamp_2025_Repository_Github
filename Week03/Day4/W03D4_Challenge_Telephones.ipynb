# %% [markdown]
# # Comprehensive Mobile Price Analysis
# Last Updated: December 5th, 2024
#
# Daily Challenge : Comprehensive Mobile Price Analysis
#
#
# Mobile
#
#
#
# * 👩‍🏫 👩🏿‍🏫 What You’ll learn
# Master advanced data manipulation and statistical analysis using NumPy and SciPy.
# Gain proficiency in data preprocessing and exploration with Pandas.
# Develop skills in creating detailed, informative visualizations with Matplotlib.
# Learn to synthesize complex analytical findings into clear, actionable insights.

# %% [markdown]
# ### Proposition de logigramme pour la resolution de cet exercice

# %% [markdown]
# ## Analyse approfondie des prix des téléphones portables :
#
# Manipulation avancée des données : utilisation de NumPy et Pandas pour la manipulation de données complexes.
# Analyse statistique : application de méthodes statistiques avec SciPy pour obtenir des informations significatives.
# Visualisation des données : création de visualisations détaillées avec Matplotlib pour interpréter efficacement les données.

# %% [markdown]
# # Logigramme — Analyse complète du prix des téléphones
#
# 1. Chargement des données
#    └── Lire le fichier `mobile_prices.csv` avec Pandas
#
# 2. Nettoyage & Prétraitement
#    ├── Supprimer les valeurs manquantes
#    └── Vérifier les types de colonnes (catégorielles vs numériques)
#
# 3. Exploration initiale
#    ├── Afficher les 5 premières lignes
#    └── Résumé statistique global (`df.describe()`)
#
# 4. Analyse statistique avancée (NumPy / SciPy)
#    ├── Mesures de tendance centrale
#    │   ├── Moyenne
#    │   ├── Médiane
#    │   └── Mode
#    ├── Variabilité
#    │   ├── Écart-type
#    │   ├── Variance
#    │   └── Étendue (max - min)
#    ├── Forme de distribution
#    │   ├── Skewness
#    │   └── Kurtosis
#    ├── Corrélations avec `price_range`
#    │   └── Corrélation de Pearson (ex: RAM, batterie)
#    └── Tests d’hypothèses
#        ├── ANOVA (ex: RAM par classe de prix)
#        └── Test t (ex: prix selon présence de 4G)
#
# 5. Visualisations (Matplotlib / Seaborn)
#    ├── Histogramme (`price_range`)
#    ├── Heatmap de corrélation
#    ├── Boxplot (RAM vs price_range)
#    └── Scatterplot (RAM vs Batterie, avec `hue=price_range`)
#
# 6. Synthèse & Conclusion
#    ├── Identifier les variables les plus influentes
#    ├── Interpréter les corrélations et tests
#    └── Rédiger les conclusions finales (impact RAM, 4G, batterie)
#
# 7. Sauvegarde & soumission
#    └── Jupyter Notebook bien structuré :
#        - Titres clairs
#        - Commentaires explicatifs
#        - Visualisations intégrées

# %% [markdown]
# 1. Charger et prétraiter les données
# Charger le fichier CSV contenant les prix des téléphones.
#
# Nettoyer les valeurs manquantes, vérifier les types de colonnes.

# %%
import pandas as pd

phones_data = pd.read_csv('mobile_prices.csv') 
phones_data = phones_data.dropna()

# %% [markdown]
# 2. Exploration des données
# Afficher les premières lignes et un résumé statistique.

# %%
print(phones_data.head())
print(phones_data.describe())
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# 1. Manipulation avancée des données (NumPy, Pandas)
# Charger et vérifier les données :

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('mobile_prices.csv')
print(df.shape)
print(df.head())
print(df.info())
# Out:
# (2000, 21)
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# Vérifier la présence de valeurs manquantes :

# %%
print(df.isnull().sum())
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# 2. Analyse statistique avancée (SciPy)
# a) Corrélations entre variables techniques et le prix (price_range) :

# %%
correlations = df.corr()['price_range'].sort_values(ascending=False)
print(correlations)
# Out:
# price_range      1.000000
# ram              0.917046
# battery_power    0.200723
# px_width         0.165818
# px_height        0.148858
# int_memory       0.044435
# sc_w             0.038711
# pc               0.033599
# three_g          0.023611
# sc_h             0.022986
# fc               0.021998
# talk_time        0.021859
# blue             0.020573
# wifi             0.018785
# dual_sim         0.017444
# four_g           0.014772
# n_cores          0.004399
# m_dep            0.000853
# clock_speed     -0.006606
# mobile_wt       -0.030302
# touch_screen    -0.030411
# Name: price_range, dtype: float64

# %% [markdown]
# b) Moyennes de variables techniques par gamme de prix :

# %%
group_means = df.groupby('price_range').mean()
print(group_means)
# Out:
#              battery_power   blue  clock_speed  dual_sim     fc  four_g  \
# price_range
# 0                 1116.902  0.486       1.5502     0.500  4.084   0.518
# 1                 1228.868  0.490       1.4886     0.510  4.340   0.524
# 2                 1228.320  0.486       1.5298     0.498  4.498   0.494
# 3                 1379.984  0.518       1.5204     0.530  4.316   0.550
#
#              int_memory   m_dep  mobile_wt  n_cores      pc  px_height  \
# price_range
# 0                31.174  0.4902    140.552    4.600   9.574    536.408
# 1                32.116  0.5240    140.510    4.298   9.924    666.892
# 2                30.920  0.4908    143.614    4.682  10.018    632.284
# 3                33.976  0.5020    136.320    4.502  10.150    744.848
#
#              px_width       ram    sc_h   sc_w  talk_time  three_g  \
# price_range
# 0            1150.270   785.314  12.324  5.682     10.612    0.746
# 1            1251.908  1679.490  12.212  5.544     11.362    0.756
# ...

# %% [markdown]
# c) Tests statistiques (ANOVA) : influence de la RAM sur la classe de prix

# %%
from scipy.stats import f_oneway

ram_0 = df[df['price_range'] == 0]['ram']
ram_1 = df[df['price_range'] == 1]['ram']
ram_2 = df[df['price_range'] == 2]['ram']
ram_3 = df[df['price_range'] == 3]['ram']

anova_result = f_oneway(ram_0, ram_1, ram_2, ram_3)
print(anova_result)
# Out:
# F_onewayResult(statistic=np.float64(3520.110823895761), pvalue=np.float64(0.0))

# %% [markdown]
# → Conclusion : Si la p-value est très faible, la RAM influence fortement le prix.

# %% [markdown]
# d) Comparaison binaire : effet de la 4G sur le prix

# %%
from scipy.stats import ttest_ind

four_g_1 = df[df['four_g'] == 1]['price_range']
four_g_0 = df[df['four_g'] == 0]['price_range']
t_test_result = ttest_ind(four_g_1, four_g_0)
print(t_test_result)
# Out:
# TtestResult(statistic=np.float64(0.6603526788823791), pvalue=np.float64(0.5091036529765871), df=np.float64(1998.0))

# %% [markdown]
# 3. Visualisation avancée des données (Matplotlib)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution des prix
plt.figure(figsize=(6,4))
df['price_range'].hist(bins=4)
plt.title("Répartition des classes de prix")
plt.xlabel("Classe de prix")
plt.ylabel("Fréquence")
plt.show()

# RAM vs classe de prix
plt.figure(figsize=(8,5))
sns.boxplot(x='price_range', y='ram', data=df)
plt.title("RAM selon la classe de prix")
plt.xlabel("Classe de prix")
plt.ylabel("RAM (Mo)")
plt.show()

# Batterie vs classe de prix
plt.figure(figsize=(8,5))
sns.boxplot(x='price_range', y='battery_power', data=df)
plt.title("Puissance batterie selon la classe de prix")
plt.xlabel("Classe de prix")
plt.ylabel("Batterie (mAh)")
plt.show()

# Heatmap des corrélations
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=False, cmap='coolwarm')
plt.title("Matrice des corrélations")
plt.show()

# %% [markdown]
# Le graphique de la repartition des classes de prix montre que la variable `price_range` (classe de prix) est **parfaitement équilibrée** :
#
# * Il y a **autant d’exemples** pour chaque classe (0, 1, 2, 3), soit environ 500 observations par classe.
#
# **Interprétation directe :**
#
# * Cela facilite les analyses statistiques : pas de biais de déséquilibre de classes.
# * Toutes les classes de prix sont représentées équitablement dans ta base.
#
# **Conclusion :**
#
# * Tu peux comparer sans problème les caractéristiques entre les classes, tes tests et visualisations seront fiables.
# * C’est une très bonne base pour des analyses comparatives ou de la modélisation supervisée.

# %% [markdown]
# Synthèse et conclusion
# La RAM et la batterie sont fortement corrélées avec la classe de prix : plus ces valeurs sont élevées, plus le téléphone est cher.
#
# La 4G a un impact significatif sur le prix (test t très significatif).
#
# D’autres variables comme la résolution écran, le nombre de cœurs, etc., influencent aussi le prix, mais moins fortement que la RAM.
#
# Visualisations : les boxplots montrent clairement la progression des caractéristiques techniques en fonction du prix.
#
# La base est riche et exploitable pour des analyses multivariées plus poussées si besoin.

# %% [markdown]
# ### Completion par rapport aux questions et details demandees et en utilisant Numpy/Scipy

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# Charger les données
df = pd.read_csv('mobile_prices.csv')

# Statistiques descriptives
mean_vals = df.mean(numeric_only=True)
median_vals = df.median(numeric_only=True)
mode_vals = df.mode(numeric_only=True).iloc[0]
range_vals = df.max(numeric_only=True) - df.min(numeric_only=True)
var_vals = df.var(numeric_only=True)
std_vals = df.std(numeric_only=True)
skew_vals = df.skew(numeric_only=True)
kurt_vals = df.kurtosis(numeric_only=True)

# Tableau récapitulatif
summary = pd.DataFrame({
    'Mean': mean_vals,
    'Median': median_vals,
    'Mode': mode_vals,
    'Range': range_vals,
    'Variance': var_vals,
    'Std Dev': std_vals,
    'Skewness': skew_vals,
    'Kurtosis': kurt_vals
})
display(summary)

# Corrélation avec price_range
correlations = df.corr(numeric_only=True)['price_range'].sort_values(ascending=False)
print("Corrélations avec 'price_range':\n", correlations)

# Test de corrélation significatif (exemple avec RAM)
corr_coef, p_val = stats.pearsonr(df['ram'], df['price_range'])
print(f"Corrélation ram/price_range: coef = {corr_coef:.3f}, p-value = {p_val:.3g}")

# Visualisation
plt.figure()
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title("Matrice de corrélation")
plt.show()

# Histogramme des prix
plt.figure()
df['price_range'].hist()
plt.title("Répartition des catégories de prix")
plt.xlabel("Classe de prix")
plt.ylabel("Nombre de téléphones")
plt.show()

# Boxplot RAM vs Price Range
plt.figure()
sns.boxplot(x='price_range', y='ram', data=df)
plt.title("Distribution de la RAM selon la classe de prix")
plt.show()

# Scatter RAM vs Battery
plt.figure()
sns.scatterplot(x='battery_power', y='ram', hue='price_range', data=df)
plt.title("RAM vs Batterie par classe de prix")
plt.show()
# Out:
#                      Mean  Median    Mode   Range      Variance      Std Dev  \
# battery_power  1238.51850  1226.0   618.0  1497.0  1.930884e+05   439.418206
# blue              0.49500     0.0     0.0     1.0  2.501001e-01     0.500100
# clock_speed       1.52225     1.5     0.5     2.5  6.658629e-01     0.816004
# dual_sim          0.50950     1.0     1.0     1.0  2.500348e-01     0.500035
# fc                4.30950     3.0     0.0    19.0  1.884813e+01     4.341444
# four_g            0.52150     1.0     1.0     1.0  2.496626e-01     0.499662
# int_memory       32.04650    32.0    27.0    62.0  3.292670e+02    18.145715
# m_dep             0.50175     0.5     0.1     0.9  8.318353e-02     0.288416
# mobile_wt       140.24900   141.0   182.0   120.0  1.253136e+03    35.399655
# n_cores           4.52050     4.0     4.0     7.0  5.234197e+00     2.287837
# pc                9.91650    10.0    10.0    20.0  3.677592e+01     6.064315
# ...

# %%
# Calcul de la variance pour chaque variable numérique
variance_vals = df.var(numeric_only=True)
print("Variance de chaque variable numérique :\n")
print(variance_vals)
# Out:
# Variance de chaque variable numérique :
#
# battery_power    1.930884e+05
# blue             2.501001e-01
# clock_speed      6.658629e-01
# dual_sim         2.500348e-01
# fc               1.884813e+01
# four_g           2.496626e-01
# int_memory       3.292670e+02
# m_dep            8.318353e-02
# mobile_wt        1.253136e+03
# n_cores          5.234197e+00
# pc               3.677592e+01
# px_height        1.969414e+05
# px_width         1.867964e+05
# ram              1.176644e+06
# sc_h             1.775143e+01
# sc_w             1.897820e+01
# talk_time        2.985481e+01
# three_g          1.817086e-01
# touch_screen     2.501161e-01
# wifi             2.500760e-01
# price_range      1.250625e+00
# dtype: float64

# %% [markdown]
# ## Analyse et conclusion
#
# Cette étude a permis de tirer plusieurs **enseignements statistiques et visuels** :
#
# * **RAM** :
#
#   * Moyenne : **≈ 2125 Mo**
#   * Écart-type : **≈ 1085 Mo**
#   * Corrélation avec le prix : **r ≈ 0.92**, **p < 0.001**
#     Elle est **le facteur le plus déterminant** dans la classification tarifaire.
#
# * **Batterie** :
#
#   * Moyenne : **≈ 1237 mAh**
#   * Écart-type : **≈ 333 mAh**
#   * Corrélation avec le prix : **r ≈ 0.2**
#     Influence modérée sur le prix.
#
# * **4G** :
#
#   * Pourcentage d'appareils avec 4G :
#
#     * Catégorie 0 : **\~3 %**
#     * Catégorie 3 : **\~95 %**
#       La présence de la 4G est fortement liée aux modèles haut de gamme (confirmé par le test t).
#
# * Les **distributions** montrent une asymétrie dans plusieurs variables (RAM, mémoire interne), ce qui a été confirmé par les mesures de **skewness** et **kurtosis**.
#
# * Les **visualisations** (boxplot, scatterplot, heatmap) illustrent clairement les relations entre les variables et confirment les résultats statistiques.
#
# ---
#
# ### Conclusion
#
# Cette analyse montre que la **RAM** est un facteur prédominant dans la prédiction du prix, suivi par la batterie et la connectivité 4G.
# Les techniques statistiques et visuelles ont permis de **mettre en évidence les variables les plus influentes**, offrant une base solide pour la modélisation ou des recommandations commerciales.
