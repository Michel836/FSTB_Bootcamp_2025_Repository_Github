# %% [markdown]
# # Exercices XP
# Dernière mise à jour : 27 janvier 2025
#
# * 👩‍🏫 👩🏿‍🏫 Ce que vous apprendrez
# Comment appliquer diverses fonctions statistiques à l'aide de SciPy
# Comprendre les distributions de probabilité et les tests d'hypothèses
# Analyser les données avec des méthodes de régression, d'ANOVA et de corrélation
#
#
# * 🛠️ Ce que vous allez créer
# Vous créerez une série de scripts Python qui effectuent différentes analyses statistiques, notamment l'exploration de données, les tests d'hypothèses, la régression linéaire, l'ANOVA, etc.

# %% [markdown]
# ## Exercice 1 : Utilisation de base de SciPy
# * Tâche : Importer la bibliothèque SciPy et explorer sa version.

# %%
# Importation de la bibliothèque principale SciPy
import scipy

# %%
# Affichage de la version installée de SciPy
# Utile pour s'assurer que la version est compatible avec les fonctionnalités utilisées
print("Version de SciPy :", scipy.__version__)
# Out:
# Version de SciPy : 1.15.3

# %% [markdown]
# ## 🌟 Exercice 2 : Statistiques descriptives
# * Tâche : Étant donné un exemple d’ensemble de données, calculez la moyenne, la médiane, la variance et l’écart type à l’aide de SciPy.
# * Exemple de jeu de données :
# data = [12, 15, 13, 12, 18, 20, 22, 21]

# %%
# Import des fonctions statistiques depuis scipy
from scipy import stats
import numpy as np  # Utilisé ici pour la variance et l'écart type

# %%
# Jeu de données fourni
data = [12, 15, 13, 12, 18, 20, 22, 21]

# %%
# Moyenne : somme des valeurs divisée par le nombre de valeurs
mean = stats.tmean(data)
print("Moyenne :", mean)
# Out:
# Moyenne : 16.625

# %%
# Médiane : valeur centrale quand les données sont triées
median = stats.scoreatpercentile(data, 50)
print("Médiane :", median)
# Out:
# Médiane : 16.5

# %%
# Variance : mesure de la dispersion des données autour de la moyenne
variance = np.var(data, ddof=0)  # ddof=0 → variance population
print("Variance :", variance)
# Out:
# Variance : 14.984375

# %%
# Écart type : racine carrée de la variance
std_dev = np.std(data, ddof=0)  # ddof=0 → écart type population
print("Écart type :", std_dev)
# Out:
# Écart type : 3.8709656418005056

# %% [markdown]
# ## 🌟 Exercice 3 : Comprendre les distributions
# * Tâche : Générer une distribution normale à l'aide de SciPy avec une moyenne de 50 et un écart type de 10. Tracer cette distribution.
# * Exemple de code :
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.stats import norm
#
# * complete your code here

# %%
# Importation des bibliothèques nécessaires
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Paramètres de la distribution normale
mu = 50         # moyenne
sigma = 10      # écart type

# %%
# Génération d'une plage de valeurs autour de la moyenne
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)

# %%
# Calcul de la densité de probabilité pour chaque valeur de x
y = norm.pdf(x, mu, sigma)

# %%
# Tracé de la courbe de la distribution normale
plt.plot(x, y)
plt.title("Distribution Normale (μ=50, σ=10)")
plt.xlabel("Valeurs")
plt.ylabel("Densité de probabilité")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 🌟 Exercice 4 : Application du test T
# * Tâche : Effectuer un test T sur deux ensembles de données générées aléatoirement.
# * Exemple de code :
# data1 = np.random.normal(50, 10, 100)
# data2 = np.random.normal(60, 10, 100)
#
# * complete your code here

# %%
# Importation des bibliothèques nécessaires
import numpy as np
from scipy import stats

# %%
# Génération de deux échantillons aléatoires suivant une distribution normale
# data1 : moyenne 50, écart type 10, 100 valeurs
# data2 : moyenne 60, écart type 10, 100 valeurs
data1 = np.random.normal(50, 10, 100)
data2 = np.random.normal(60, 10, 100)

# %%
# Test t de Student pour échantillons indépendants
# H0 : les deux échantillons proviennent de populations avec la même moyenne
t_stat, p_value = stats.ttest_ind(data1, data2)

# %%
# Affichage des résultats du test
print("Statistique t :", t_stat)
print("Valeur p :", p_value)
# Out:
# Statistique t : -8.13315659554794
# Valeur p : 4.5120988276603405e-14

# %% [markdown]
# * Une p-value < 0.05 suggère un rejet de H0 (différence significative entre les moyennes)

# %% [markdown]
# ## Exercice 5 : Analyse de régression linéaire
# * Objectif : Appliquer la régression linéaire à un ensemble de données et interpréter les résultats.
#
# * Tâche : Étant donné un ensemble de données sur les prix des logements ( house_prices) et leurs tailles correspondantes ( house_sizes), utilisez la régression linéaire pour prédire le prix d'une maison en fonction de sa taille.
# * Ensemble de données :
# house_sizes: [50, 70, 80, 100, 120] (en mètres carrés)
# house_prices: [150 000, 200 000, 210 000, 250 000, 280 000] (en unités monétaires)
# * Questions :
# Quelle est la pente et l'interception de la droite de régression ?
# Prédisez le prix d'une maison de 90 mètres carrés.
# Interpréter la signification de la pente dans le contexte des prix de l’immobilier.

# %%
# Importation des bibliothèques nécessaires
import numpy as np
from scipy import stats

# %%
# Données : tailles des maisons (m²) et prix correspondants
house_sizes = np.array([50, 70, 80, 100, 120])
house_prices = np.array([150000, 200000, 210000, 250000, 280000])

# %%
# Régression linéaire : calcule la pente, l'interception, r, p-value, erreur std
slope, intercept, r_value, p_value, std_err = stats.linregress(house_sizes, house_prices)

# %%
# Affichage des coefficients
print("Pente :", slope)
print("Interception :", intercept)
# Out:
# Pente : 1828.7671232876712
# Interception : 64383.56164383562

# %%
# Prédiction du prix pour une maison de 90 m²
predicted_price = slope * 90 + intercept
print("Prix prédit pour une maison de 90 m² :", predicted_price)
# Out:
# Prix prédit pour une maison de 90 m² : 228972.60273972602

# %% [markdown]
# ### Interprétation :
# * La pente représente l'augmentation moyenne du prix pour chaque mètre carré supplémentaire.
# * Ici, chaque m² supplémentaire fait augmenter le prix d'environ `slope` unités monétaires.

# %% [markdown]
# ## 🌟 Exercice 6 : Comprendre l’ANOVA
# * Objectif : Tester la compréhension de l'ANOVA et de son application.
#
# * Tâche : Trois engrais différents sont appliqués à trois groupes de plantes distincts pour tester leur efficacité. La croissance en centimètres est enregistrée.
# * Ensemble de données :
# fertilizer_1: [5, 6, 7, 6, 5]
# fertilizer_2: [7, 8, 7, 9, 8]
# fertilizer_3: [4, 5, 4, 3, 4]
# * Questions :
# Effectuez un test ANOVA sur les données fournies. Quelles sont les valeurs F et P ?
# Sur la base de la valeur P, les engrais ont-ils des effets significativement différents sur la croissance des plantes ?
# Expliquez ce qui se passerait si la valeur p était supérieure à 0,05.

# %%
# Importation de la fonction ANOVA (analyse de la variance) et numpy
from scipy import stats
import numpy as np

# %%
# Données de croissance des plantes selon 3 types d'engrais
fertilizer_1 = [5, 6, 7, 6, 5]
fertilizer_2 = [7, 8, 7, 9, 8]
fertilizer_3 = [4, 5, 4, 3, 4]

# %%
# Application du test ANOVA à un facteur (one-way ANOVA)
f_stat, p_value = stats.f_oneway(fertilizer_1, fertilizer_2, fertilizer_3)

# %%
# Affichage des résultats
print("Valeur F :", f_stat)
print("Valeur p :", p_value)
# Out:
# Valeur F : 28.52631578947368
# Valeur p : 2.754267209804844e-05

# %% [markdown]
# ### Interprétation :
# * Si p < 0.05 : on rejette l'hypothèse nulle → au moins un engrais a un effet différent
# * Si p > 0.05 : on ne peut pas conclure à une différence significative entre les engrais

# %%
if p_value < 0.05:
    print("Résultat : Les engrais ont des effets significativement différents.")
else:
    print("Résultat : Aucune différence significative détectée entre les engrais.")
# Out:
# Résultat : Les engrais ont des effets significativement différents.

# %% [markdown]
# ## Exercice 7 : Distributions de probabilité (facultatif)
# * Travailler avec une distribution binomiale : calculer les probabilités pour différents nombres de succès.
# * Exemple : Calculer la probabilité d’obtenir exactement 5 faces en 10 lancers de pièce.

# %%
# Importation de la distribution binomiale depuis scipy
from scipy.stats import binom

# %%
# Paramètres de la distribution binomiale
n = 10      # nombre d'essais (lancers de pièce)
p = 0.5     # probabilité de succès (obtenir face)

# %%
# Calcul de la probabilité d'obtenir exactement 5 faces
k = 5
prob = binom.pmf(k, n, p)  # pmf = probabilité de masse (discrète)

print(f"Probabilité d’obtenir exactement {k} faces sur {n} lancers :", prob)
# Out:
# Probabilité d’obtenir exactement 5 faces sur 10 lancers : 0.24609375000000003

# %% [markdown]
# ## 🌟 Exercice 8 : Coefficients de corrélation (facultatif)
# * Calculez les coefficients de corrélation de Pearson et de Spearman entre deux variables dans un ensemble de données.
# * Exemple dans le code :data = pd.DataFrame({'age': [23, 25, 30, 35, 40], 'income': [35000, 40000, 50000, 60000, 70000]})

# %%
# Importation des bibliothèques nécessaires
import pandas as pd
from scipy.stats import pearsonr, spearmanr

# %%
# Création de l'ensemble de données
data = pd.DataFrame({
    'age': [23, 25, 30, 35, 40],
    'income': [35000, 40000, 50000, 60000, 70000]
})

# %%
# Calcul du coefficient de corrélation de Pearson (linéaire)
pearson_corr, _ = pearsonr(data['age'], data['income'])
print("Coefficient de corrélation de Pearson :", pearson_corr)
# Out:
# Coefficient de corrélation de Pearson : 0.9996907452347201

# %%
# Calcul du coefficient de corrélation de Spearman (monotone)
spearman_corr, _ = spearmanr(data['age'], data['income'])
print("Coefficient de corrélation de Spearman :", spearman_corr)
# Out:
# Coefficient de corrélation de Spearman : 0.9999999999999999
