# %% [markdown]
# # Exercices XP
# Dernière mise à jour : 19 mai 2025
#
# 👩‍🏫 👩🏿‍🏫 Ce que vous apprendrez
# Héritage
# Méthodes et attributs de classe
# Polymorphisme
# Exceptions
# super()fonction

# %% [markdown]
# 🌟 Exercice 1 : Animaux de compagnie
# Sujets clés de Python :
#
# Héritage
# Instanciation de classe
# Listes
# Polymorphisme
#
#
# Instructions:
#
# PetsUtilisez les classes et fournies Catpour créer une Siameserace, instancier des objets chat et utiliser la Petsclasse pour les gérer.
# Consultez l'exemple ci-dessous avant de vous lancer.
#
#
#
# Étape 1 : Créer la classe Siamoise
#
# Créez une classe appelée Siamesequi hérite de la Catclasse.
# Vous pouvez ajouter des attributs ou des méthodes spécifiques pour la Siameserace, ou le laisser tel quel s'il n'y a pas de comportements uniques.nous devrions leur dire quoi ajouter, peut-être un nouvel attribut ou de nouvelles méthodes
#
#
# Étape 2 : Créer une liste d'instances de chat
#
# Créez une liste appelée all_catscontenant des instances de Bengal, Chartreuxet Siamesede chats.
# Exemple :all_cats = [bengal_obj, chartreux_obj, siamese_obj]
# Donnez à chaque chat un nom et un âge.
#
#
# Étape 3 : Créer une instance d'animaux de compagnie
#
# Créez une instance de la Petsclasse appelée sara_pets, en passant la all_catsliste comme argument.
#
#
# Étape 4 : Promenez les chats
#
# Appelez la walk()méthode sur l' sara_petsinstance.
# Cela devrait imprimer le résultat de l'appel de la walk()méthode sur chaque chat de la liste.
#
#
# Exemple:
#
# class Pets():
#     def __init__(self, animals):
#         self.animals = animals
#
#     def walk(self):
#         for animal in self.animals:
#             print(animal.walk())
#
# class Cat():
#     is_lazy = True
#
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     def walk(self):
#         return f'{self.name} is just walking around'
#
# class Bengal(Cat):
#     def sing(self, sounds):
#         return f'{sounds}'
#
# class Chartreux(Cat):
#     def sing(self, sounds):
#         return f'{sounds}'
#
#
# Étape 1 : Créer la classe Siamoise
#
# Étape 2 : Créer une liste d’instances de chat
#
# Étape 3 : Créer une instance Pets de la liste des instances de chat
#
# sara_pets = Pets(all_cats)
#
# Étape 4 : Promenez les chats
# sara_pets.walk()

# %% [markdown]
# # Résolution

# %%
# 1 : Définition des classes de base

# Classe Pets qui gère plusieurs animaux
class Pets():
    def __init__(self, animals):
        # animals : liste d'objets animaux
        self.animals = animals

    def walk(self):
        # Pour chaque animal de la liste, on appelle sa méthode walk()
        for animal in self.animals:
            print(animal.walk())

# Classe de base Cat
class Cat():
    is_lazy = True

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def walk(self):
        # Méthode commune à tous les chats
        return f'{self.name} se promène simplement.'

# %%
# 2 : Définition des classes de races de chats

# Bengal hérite de Cat
class Bengal(Cat):
    def sing(self, sounds):
        return f'{self.name} chante : {sounds}'

# Chartreux hérite de Cat
class Chartreux(Cat):
    def sing(self, sounds):
        return f'{self.name} chante : {sounds}'

# Étape 1 : Création de la classe Siamese (Siamoise) qui hérite de Cat
class Siamese(Cat):
    # Attribut ou méthode spécifique, par exemple couleur des yeux
    def __init__(self, name, age, eye_color='Bleu'):
        super().__init__(name, age)
        self.eye_color = eye_color

    # Nouvelle méthode
    def describe(self):
        return f'{self.name} a des yeux {self.eye_color}'

# %%
# 3 : Création des instances de chats

# Étape 2 : On crée des objets pour chaque race, avec nom et âge
bengal_cat = Bengal("Tigrou", 3)
chartreux_cat = Chartreux("Grisou", 5)
siamese_cat = Siamese("Mimi", 2)

# On met les objets dans une liste
all_cats = [bengal_cat, chartreux_cat, siamese_cat]

# Vérification rapide
for cat in all_cats:
    print(f"{cat.name}, {cat.age} ans")
# Out:
# Tigrou, 3 ans
# Grisou, 5 ans
# Mimi, 2 ans

# %%
# 4 : Création de l'instance Pets

# Étape 3 : On crée une instance de Pets avec la liste de chats
sara_pets = Pets(all_cats)

# %%
# 5 : Promener les chats

# Étape 4 : On appelle la méthode walk sur l'objet sara_pets
sara_pets.walk()
# Out:
# Tigrou se promène simplement.
# Grisou se promène simplement.
# Mimi se promène simplement.

# %% [markdown]
# # 🌟 Exercice 2 : Chiens
# Objectif : créer une Dogclasse avec des méthodes pour aboyer, courir vite et se battre.
#
#
#
# Sujets clés de Python :
#
# Classes et objets
# Méthodes
# Attributs
#
#
# Instructions:
#
# Étape 1 : Créer la classe Chien
#
# Créez une classe appelée Dogavec les attributs name, age, et weight.
# Implémentez une bark()méthode qui renvoie «aboie”.
# Implémentez une run_speed()méthode qui renvoie weight / age * 10.
# Implémentez une fight(other_dog)méthode qui renvoie une chaîne indiquant quel chien a gagné le combat, en fonction de run_speed * weight.
#
#
# Étape 2 : Créer des instances de chien
#
# Créez trois instances de la Dogclasse avec des noms, des âges et des poids différents.
#
#
# Étape 3 : Méthodes de test du chien
#
# Appelez les méthodes bark(), run_speed(), et fight()sur les instances de chien pour tester leur fonctionnalité.
#
#
# Exemple (conceptuel, sans solution directe) :
#
# class Dog:
#     def __init__(self, name, age, weight):
#         # ... code to initialize attributes ...
#
#     def bark(self):
#         # ... code to return bark message ...
#
#     def run_speed(self):
#         # ... code to return run speed ...
#
#     def fight(self, other_dog):
#         # ... code to determine and return winner ...
#
# # Step 2: Create dog instances
# #... your code here
#
# # Step 3: Test dog methods
# print(dog1.bark())
# print(dog2.run_speed())
# print(dog1.fight(dog2))

# %% [markdown]
# # Résolution

# %%
# 1 : Définition de la classe Dog

class Dog:
    def __init__(self, name, age, weight):
        # Initialisation des attributs de base
        self.name = name
        self.age = age
        self.weight = weight

    def bark(self):
        # Méthode pour aboyer
        return f"{self.name} aboie !"

    def run_speed(self):
        # Calcul de la vitesse de course
        return self.weight / self.age * 10

    def fight(self, other_dog):
        # Calcul de la puissance de chaque chien
        my_power = self.run_speed() * self.weight
        other_power = other_dog.run_speed() * other_dog.weight

        # Comparaison des puissances
        if my_power > other_power:
            return f"{self.name} gagne le combat contre {other_dog.name} !"
        elif my_power < other_power:
            return f"{other_dog.name} gagne le combat contre {self.name} !"
        else:
            return "Match nul !"

# %%
# 2 : Création des instances de chien

# Étape 2 : Création de 3 chiens
dog1 = Dog("Rex", 4, 20)
dog2 = Dog("Max", 6, 25)
dog3 = Dog("Fido", 3, 10)

# Vérification rapide
for dog in [dog1, dog2, dog3]:
    print(f"{dog.name}, {dog.age} ans, {dog.weight} kg")
# Out:
# Rex, 4 ans, 20 kg
# Max, 6 ans, 25 kg
# Fido, 3 ans, 10 kg

# %%
# 3 : Test des méthodes

# Étape 3 : Test des méthodes bark(), run_speed() et fight()

# Test des aboiements
print(dog1.bark())
print(dog2.bark())
print(dog3.bark())

# Test de la vitesse
print(f"{dog1.name} court à {dog1.run_speed():.2f} km/h")
print(f"{dog2.name} court à {dog2.run_speed():.2f} km/h")
print(f"{dog3.name} court à {dog3.run_speed():.2f} km/h")

# Test des combats
print(dog1.fight(dog2))
print(dog2.fight(dog3))
print(dog1.fight(dog3))
# Out:
# Rex aboie !
# Max aboie !
# Fido aboie !
# Rex court à 50.00 km/h
# Max court à 41.67 km/h
# Fido court à 33.33 km/h
# Max gagne le combat contre Rex !
# Max gagne le combat contre Fido !
# Rex gagne le combat contre Fido !

# %% [markdown]
# # 🌟 Exercice 3 : Chiens domestiqués
# Objectif : Créer une PetDogclasse qui hérite Doget ajoute des entraînements et des astuces.
#
#
#
# Sujets clés de Python :
#
# Héritage
# super()fonction
# *args
# Module aléatoire
#
#
# Instructions:
#
# Étape 1 : Importer la classe Dog
#
# Dans un nouveau fichier Python, importez la Dogclasse de l’exercice précédent.
#
#
# Étape 2 : Créer la classe PetDog
#
# Créez une classe appelée PetDogqui hérite de la Dogclasse.
# Ajoutez un trainedattribut à la __init__méthode, avec une valeur par défaut de False.
# trainedsignifie que le chien est entraîné à faire quelques tours.
# Implémentez une train()méthode qui imprime la sortie de bark()et définit trainedsur True.
# Implémentez une play(*args)méthode qui imprime «tous jouent ensemble".
# *argsCette méthode contient une liste d'instances de chien.
# Implémentez une do_a_trick()méthode qui affiche une astuce aléatoire si trainedest True.
# Utilisez cette liste pour les astuces aléatoires :
# tricks = ["does a barrel roll", "stands on his back legs", "shakes your hand", "plays dead"]
# choisissez un index de rendu à chaque appel de la méthode.
#
#
# Étape 3 : tester les méthodes PetDog
#
# Créez des instances de la PetDogclasse et testez les méthodes train(), play(*args), et .do_a_trick()
#
#
# Exemple:
#
# # In a new file
# # import the Dog class
#
# class PetDog(Dog):
#     def __init__(self, name, age, weight): <mark> no need to put the details in the function, you are giving the solution</mark>
#         super().__init__(name, age, weight)
#         self.trained = False
#
#     def train(self): <mark> no need to put the details in the function, you are giving the solution</mark>
#         print(self.bark())
#         self.trained = True
#
#     def play(self, *args):
#         # ... code to print play message ...
#
#     def do_a_trick(self): <mark> no need to put the details in the function, you are giving the solution</mark>
#         if self.trained:
#             tricks = ["does a barrel roll", "stands on his back legs", "shakes your hand", "plays dead"]
#             print(f"{self.name} {random.choice(tricks)}")
#
# # Test PetDog methods
# my_dog = PetDog("Fido", 2, 10)
# my_dog.train()
# my_dog.play("Buddy", "Max")
# my_dog.do_a_trick()

# %% [markdown]
# # Résolution

# %%
# 1 : Import des modules et définition (ou import) de Dog

import random

# Pour ce notebook, on redéfinit Dog ici (normalement à importer d’un fichier séparé)
class Dog:
    def __init__(self, name, age, weight):
        self.name = name
        self.age = age
        self.weight = weight

    def bark(self):
        return f"{self.name} aboie !"

    def run_speed(self):
        return self.weight / self.age * 10

    def fight(self, other_dog):
        my_power = self.run_speed() * self.weight
        other_power = other_dog.run_speed() * other_dog.weight
        if my_power > other_power:
            return f"{self.name} gagne contre {other_dog.name} !"
        elif my_power < other_power:
            return f"{other_dog.name} gagne contre {self.name} !"
        else:
            return "Match nul !"

# %%
# 2 : Définition de la classe PetDog

class PetDog(Dog):
    def __init__(self, name, age, weight):
        # Appelle le constructeur de Dog
        super().__init__(name, age, weight)
        # Attribut qui indique si le chien est entraîné
        self.trained = False

    def train(self):
        # Aboie puis devient entraîné
        print(self.bark())
        self.trained = True

    def play(self, *args):
        # args : noms des autres chiens (ou objets)
        names = [self.name] + [dog if isinstance(dog, str) else dog.name for dog in args]
        print(f"{', '.join(names)} jouent ensemble !")

    def do_a_trick(self):
        # Si entraîné, affiche une astuce aléatoire
        if self.trained:
            tricks = [
                "fait un tonneau",
                "se met debout sur ses pattes arrière",
                "te serre la main",
                "fait le mort"
            ]
            print(f"{self.name} {random.choice(tricks)}")
        else:
            print(f"{self.name} n'est pas encore entraîné.")

# %%
# 3 : Test des méthodes de PetDog

# Création d'instances
dog1 = PetDog("Rex", 3, 18)
dog2 = PetDog("Max", 5, 22)
dog3 = PetDog("Buddy", 4, 20)

# Test train()
dog1.train()

# Test play() avec plusieurs chiens (on peut passer les objets ou juste les noms)
dog1.play(dog2, dog3)
# ou bien dog1.play("Max", "Buddy")

# Test do_a_trick()
dog1.do_a_trick()
dog2.do_a_trick()  # pas entraîné, donc ne fait rien
# Out:
# Rex aboie !
# Rex, Max, Buddy jouent ensemble !
# Rex fait un tonneau
# Max n'est pas encore entraîné.

# %% [markdown]
# # 🌟 Exercice 4 : Classes familiales et personnelles
# But:
#
# Entraînez-vous à travailler avec des classes et des interactions d'objets en modélisant une famille et ses membres.
#
#
#
# Sujets clés de Python :
#
# Classes et objets
# Méthodes d'instance
# Interaction d'objets
# Listes et boucles
# Instructions conditionnelles ( if/else)
# Formatage des chaînes (chaînes f)
#
#
# Instructions:
#
# Étape 1 : Créer la Personclasse
#
# Définissez une Personclasse avec les attributs suivants :
# first_name
# age
# last_name(chaîne, doit être initialisée comme une chaîne vide)
# Ajoutez une méthode appelée is_18():
# Il devrait revenir Truesi la personne a 18 ans ou plus, sinon False.
#
#
# Étape 2 : Créer la Familyclasse
#
# Définir une Familyclasse avec :
# Un last_nameattribut
# Une membersliste qui stockera Persondes objets (doit être initialisée comme une liste vide)
#
# Ajoutez une méthode appelée born(first_name, age):
#
# Il devrait créer un nouvel Personobjet avec le prénom et l'âge donnés.
# Il faudrait attribuer le nom de famille à la personne.
# Il faudrait ajouter cette nouvelle personne à la membersliste.
#
# Ajoutez une méthode appelée check_majority(first_name):
#
# Il devrait rechercher membersdans la liste une personne avec cela first_name.
# Si la personne existe, appelez sa is_18()méthode.
# Si la personne a plus de 18 ans, indiquez :
# "You are over 18, your parents Jane and John accept that you will go out with your friends"
# Sinon, imprimez :
#
# "Sorry, you are not allowed to go out with your friends."
# Ajoutez une méthode appelée family_presentation():
#
# Il devrait imprimer le nom de famille.
# Ensuite, il devrait imprimer le prénom et l'âge de chaque membre de la famille.
#
#
# Comportement attendu :
#
# Une fois mis en œuvre, votre programme devrait vous permettre de :
#
# Créez une famille avec un nom de famille.
# Ajoutez des membres à la famille en utilisant la born()méthode.
# Utilisé check_majority()pour voir si quelqu'un est autorisé à sortir.
# Afficher les informations familiales avec family_presentation().
# N'oubliez pas de tester vos classes en créant une instance de Family, en ajoutant des membres et en appelant chaque méthode pour voir le résultat attendu.

# %% [markdown]
# # Résolution

# %%
# 1 : Définition de la classe Person

class Person:
    def __init__(self, first_name, age):
        self.first_name = first_name
        self.age = age
        self.last_name = ""  # Initialisé comme chaîne vide

    def is_18(self):
        # Retourne True si la personne a 18 ans ou plus, sinon False
        return self.age >= 18

# %%
# 2 : Définition de la classe Family

class Family:
    def __init__(self, last_name):
        self.last_name = last_name
        self.members = []  # Liste vide pour stocker les Person

    def born(self, first_name, age):
        # Crée un nouvel objet Person, définit son nom de famille et l'ajoute à la liste
        person = Person(first_name, age)
        person.last_name = self.last_name
        self.members.append(person)

    def check_majority(self, first_name):
        # Cherche la personne avec ce prénom et vérifie la majorité
        found = False
        for person in self.members:
            if person.first_name == first_name:
                found = True
                if person.is_18():
                    print("You are over 18, your parents Jane and John accept that you will go out with your friends")
                else:
                    print("Sorry, you are not allowed to go out with your friends.")
        if not found:
            print("Person not found in the family.")

    def family_presentation(self):
        # Affiche le nom de famille et la liste des membres (prénom et âge)
        print(f"Nom de famille : {self.last_name}")
        print("Membres :")
        for person in self.members:
            print(f"- {person.first_name}, {person.age} ans")

# %%
# 3 : Tests des classes Family et Person

# Création d'une famille
smith_family = Family("Smith")

# Ajout de membres
smith_family.born("Alice", 17)
smith_family.born("Bob", 20)
smith_family.born("Charlie", 12)

# Vérification de la majorité pour chaque membre
smith_family.check_majority("Alice")
smith_family.check_majority("Bob")
smith_family.check_majority("Charlie")
smith_family.check_majority("Dave")  # test personne absente

# Affichage de la présentation de la famille
smith_family.family_presentation()
# Out:
# Sorry, you are not allowed to go out with your friends.
# You are over 18, your parents Jane and John accept that you will go out with your friends
# Sorry, you are not allowed to go out with your friends.
# Person not found in the family.
# Nom de famille : Smith
# Membres :
# - Alice, 17 ans
# - Bob, 20 ans
# - Charlie, 12 ans
