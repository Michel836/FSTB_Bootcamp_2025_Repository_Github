# %% [markdown]
# # Daily challenge: Old MacDonald’s Farm fait le 11-06-2025
# Last Updated: May 5th, 2025
#
# 👩‍🏫 👩🏿‍🏫 What You’ll learn
# Classes and Objects
# Dictionaries
# String Formatting
# Methods
# List manipulation and sorting
#
#
# Key Python Topics:
#
# Classes and Objects
# Dictionaries
# String Formatting
# Methods
# List manipulation (sorted())
# Conditional logic (if)
# String concatenation
#
# ## Instructions: Old MacDonald’s Farm
#
# You are given example code and output. Your task is to create a Farm class that produces the same output.
#
#
#
# ### Step 1: Create the Farm Class
#
# Create a class called Farm.
# This class will represent a farm and its animals.
#
#
# ### Step 2: Implement the __init__ Method
#
# The Farm class should have an __init__ method.
# It should take one parameter: farm_name.
# Inside __init__, create two attributes: name to store the farm’s name and animals to store the animals (initialize as an empty dictionary).
#
#
# ### Step 3: Implement the add_animal Method
#
# Create a method called add_animal.
# It should take two parameters: animal_type and count (with a default value of 1). Count is the quantity of the animal that will be added to the animal dictionary.
# The dictionary will look like this:
# {'cow': 1, 'pig':3, 'horse': 2}
# If the animal_type already exists in the animals dictionary, increment its count by count.
# If it doesn’t exist, add it to the dictionary as the key and with the given count as value.
#
#
# ### Step 4: Implement the get_info Method
#
# Create a method called get_info.
# It should return a string that displays the farm’s name, the animals and their counts, and the “E-I-E-I-0!” phrase.
# Format the output to match the provided example.
# Use string formatting to align the animal names and counts into columns.
#
#
# ### Step 5: Test Your Code
#
# Create a Farm object and call the add_animal and get_info methods.
# Verify that the output matches the provided example.
#
#
# ### Example:
#
# class Farm:
#     def __init__(self, farm_name):
#         # ... code to initialize name and animals attributes ...
#
#     def add_animal(self, animal_type, count):
#         # ... code to add or update animal count in animals dictionary ...
#
#     def get_info(self):
#         # ... code to format animal info from animals dictionary ...
#
#
# #### Test the code
# macdonald = Farm("McDonald")
# macdonald.add_animal('cow', 5)
# macdonald.add_animal('sheep')
# macdonald.add_animal('sheep')
# macdonald.add_animal('goat', 12)
# print(macdonald.get_info())
# #output:
# #### McDonald's farm
#
# #### cow : 5
# #### sheep : 2
# #### goat : 12
#
# ####     E-I-E-I-0!
#
#
# Bonus: Expand The Farm
#
#
#
# ### Step 6: Implement the get_animal_types Method
#
# Add a method called get_animal_types to the Farm class.
# This method should return a sorted list of all animal types (keys from the animals dictionary).
# Use the sorted() function to sort the list.
#
#
# ### Step 7: Implement the get_short_info Method
#
# Add a method called get_short_info to the Farm class.
# This method should return a string like “McDonald’s farm has cows, goats and sheeps.”.
# Call the get_animal_types method to get the list of animals.
# Construct the string, adding an “s” to the animal name if its count is greater than 1.
# Use string formatting to create the output.

# %% [markdown]
# # 1 : Définition de la classe Farm

# %%
# Définition de la classe Farm (Ferme)
class Farm:
    def __init__(self, farm_name):
        # Le nom de la ferme (ex : "McDonald")
        self.name = farm_name

        # Dictionnaire vide pour stocker les animaux
        # Les clés sont les types d'animaux (ex : 'cow')
        # Les valeurs sont le nombre de chaque animal (ex : 5)
        self.animals = {}

    # Méthode pour ajouter des animaux à la ferme
    # animal_type : le type d'animal (ex : 'cow')
    # count : combien en ajouter (par défaut 1)
    def add_animal(self, animal_type, count=1):
        # Si l'animal existe déjà, on augmente la quantité
        if animal_type in self.animals:
            self.animals[animal_type] += count
        # Sinon, on l'ajoute avec la quantité donnée
        else:
            self.animals[animal_type] = count

    # Méthode pour retourner une chaîne qui présente la ferme et ses animaux
    def get_info(self):
        # Commence par le nom de la ferme
        result = f"{self.name}'s farm\n\n"
        # Pour chaque animal, on ajoute une ligne avec le nom et la quantité
        for animal, qty in self.animals.items():
            # f"{animal:<10}" aligne le nom à gauche sur 10 caractères
            result += f"{animal:<10} : {qty}\n"
        # Ajoute la phrase de la chanson
        result += "\n    E-I-E-I-0!"
        # Retourne tout le texte prêt à afficher
        return result

# %% [markdown]
# # 2 : Méthodes bonus, avec explications

# %%
# Méthode pour récupérer les types d'animaux triés (par ordre alphabétique)
def get_animal_types(self):
    # On récupère les clés du dictionnaire (types d'animaux) et on les trie
    return sorted(self.animals.keys())

# Méthode pour une phrase courte présentant les animaux de la ferme
def get_short_info(self):
    # On récupère la liste triée des types d'animaux
    animals_sorted = self.get_animal_types()
    animals_names = []  # Liste pour stocker les noms à afficher

    for animal in animals_sorted:
        # Si on a plus d'un animal, on ajoute un 's' à la fin (pluriel en anglais)
        name = animal + 's' if self.animals[animal] > 1 else animal
        animals_names.append(name)

    # Mise en forme de la phrase selon le nombre d'animaux
    if len(animals_names) == 1:
        animal_str = animals_names[0]
    elif len(animals_names) == 2:
        # Pour deux éléments, séparés par "and"
        animal_str = ' and '.join(animals_names)
    else:
        # Pour plus de deux éléments, virgules puis "and" avant le dernier
        animal_str = ', '.join(animals_names[:-1]) + ' and ' + animals_names[-1]

    # Retourne la phrase finale
    return f"{self.name}'s farm has {animal_str}."

# On ajoute dynamiquement ces méthodes à la classe Farm
Farm.get_animal_types = get_animal_types
Farm.get_short_info = get_short_info

# %% [markdown]
# # 3 : Utilisation et tests

# %%
# On crée une nouvelle ferme avec le nom "McDonald"
macdonald = Farm("McDonald")

# On ajoute 5 vaches
macdonald.add_animal('cow', 5)
# On ajoute 1 mouton (sheep)
macdonald.add_animal('sheep')
# Encore 1 mouton
macdonald.add_animal('sheep')
# On ajoute 12 chèvres (goats)
macdonald.add_animal('goat', 12)

# On affiche les informations complètes de la ferme
print(macdonald.get_info())

# On affiche la liste triée des types d'animaux (ex : ['cow', 'goat', 'sheep'])
print(macdonald.get_animal_types())

# On affiche une phrase courte récapitulative (ex : "McDonald's farm has cows, goats and sheeps.")
print(macdonald.get_short_info())
# Out:
# McDonald's farm
#
# cow        : 5
# sheep      : 2
# goat       : 12
#
#     E-I-E-I-0!
# ['cow', 'goat', 'sheep']
# McDonald's farm has cows, goats and sheeps.

# %% [markdown]
# ## Voici la progression logique pour réaliser cet exercice, étape par étape :
#
# ### 1. Définir ce qu’on veut modéliser
# On veut une ferme qui peut stocker des animaux et savoir combien il y en a pour chaque espèce.
#
# ### 2. Créer la classe Farm
# On crée une classe Farm qui va représenter la ferme.
#
# On ajoute un attribut pour le nom de la ferme.
#
# On ajoute un attribut pour les animaux (un dictionnaire vide au départ).
#
# ### 3. Ajouter des animaux
# On crée une méthode add_animal.
#
# Si l’animal existe déjà dans le dictionnaire, on incrémente le nombre.
#
# Sinon, on ajoute le nouvel animal avec sa quantité.
#
# ### 4. Afficher les infos de la ferme
# On crée une méthode get_info.
#
# Elle formate le nom de la ferme, liste tous les animaux avec leur quantité, puis ajoute la phrase finale (“E-I-E-I-0!”).
#
# ### 5. Tester le code
# On crée une ferme.
#
# On ajoute des animaux.
#
# On affiche les informations.
#
# ### (Bonus) 6. Améliorer avec des méthodes bonus
# On crée une méthode pour lister les types d’animaux, triés par ordre alphabétique.
#
# On crée une méthode pour générer une phrase courte (“La ferme a des vaches, chèvres et moutons.”).
#
# ## Résumé très simple :
#
# Créer la classe et les attributs
#
# Ajouter les animaux
#
# Afficher le contenu
#
# Tester
